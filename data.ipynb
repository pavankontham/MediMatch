# %%
import sqlite3
import pandas as pd

# Path to your database
db_path = 'chembl_35/chembl_35_sqlite/chembl_35.db'

# Connect
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# List available tables
tables = cursor.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
print("Available tables:")
for table in tables:
    print("-", table[0])
# Out:
# Available tables:
# - action_type
# - assay_type
# - chembl_id_lookup
# - confidence_score_lookup
# - curation_lookup
# - chembl_release
# - source
# - relationship_type
# - target_type
# - variant_sequences
# - bioassay_ontology
# - data_validity_lookup
# - activity_smid
# - activity_stds_lookup
# - assay_classification
# - atc_classification
# - bio_component_sequences
# - component_sequences
# - protein_classification
# - domains
# - go_classification
# - structural_alert_sets
# - products
# - frac_classification
# - hrac_classification
# - irac_classification
# - research_stem
# - organism_class
# - patent_use_codes
# - usan_stems
# - version
# - cell_dictionary
# - docs
# - target_dictionary
# - tissue_dictionary
# - molecule_dictionary
# - activity_supp
# - component_class
# - component_domains
# - component_go
# - component_synonyms
# - structural_alerts
# - defined_daily_dose
# - product_patents
# - protein_class_synonyms
# - research_companies
# - assays
# - compound_records
# - binding_sites
# - biotherapeutics
# - compound_properties
# - compound_structural_alerts
# - compound_structures
# - molecule_atc_classification
# - molecule_frac_classification
# - molecule_hierarchy
# - molecule_hrac_classification
# - molecule_irac_classification
# - molecule_synonyms
# - target_components
# - target_relations
# - activities
# - assay_class_map
# - assay_parameters
# - biotherapeutic_components
# - drug_indication
# - drug_mechanism
# - drug_warning
# - formulations
# - metabolism
# - site_components
# - activity_properties
# - activity_supp_map
# - indication_refs
# - ligand_eff
# - mechanism_refs
# - metabolism_refs
# - predicted_binding_domains
# - warning_refs
# - sqlite_stat1

# %%
query = """
SELECT md.chembl_id, cs.canonical_smiles
FROM molecule_dictionary md
JOIN compound_structures cs ON md.molregno = cs.molregno
LIMIT 10;
"""
df_smiles = pd.read_sql_query(query, conn)
df_smiles.head()
# Out:
#       chembl_id                                  canonical_smiles
# 0    CHEMBL6329      Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccccc1Cl
# 1    CHEMBL6328   Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(C#N)cc1
# 2  CHEMBL265667  Cc1cc(-n2ncc(=O)[nH]c2=O)cc(C)c1C(O)c1ccc(Cl)cc1
# 3    CHEMBL6362      Cc1ccc(C(=O)c2ccc(-n3ncc(=O)[nH]c3=O)cc2)cc1
# 4  CHEMBL267864    Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(Cl)cc1

# %%
def show_columns(table_name):
    query = f"PRAGMA table_info({table_name})"
    cols = pd.read_sql_query(query, conn)
    print(f"\n📊 Columns in table `{table_name}`:\n")
    print(cols[['name', 'type']])

# List columns in key tables
for table in [
    'activities',
    'molecule_dictionary',
    'compound_structures',
    'target_dictionary',
    'drug_indication',
    'assays'
]:
    show_columns(table)
# Out:
# 📊 Columns in table `activities`:
#
#                      name           type
# 0             activity_id         BIGINT
# 1                assay_id         BIGINT
# 2                  doc_id         BIGINT
# 3               record_id         BIGINT
# 4                molregno         BIGINT
# 5       standard_relation    VARCHAR(50)
# 6          standard_value        NUMERIC
# 7          standard_units   VARCHAR(100)
# 8           standard_flag       SMALLINT
# 9           standard_type   VARCHAR(250)
# 10       activity_comment  VARCHAR(4000)
# 11  data_validity_comment    VARCHAR(30)
# 12    potential_duplicate       SMALLINT
# 13          pchembl_value  NUMERIC(4, 2)
# 14           bao_endpoint    VARCHAR(11)
# 15               uo_units    VARCHAR(10)
# 16             qudt_units    VARCHAR(70)
# 17                   toid        INTEGER
# 18            upper_value        NUMERIC
# 19   standard_upper_value        NUMERIC
# 20                 src_id        INTEGER
# 21                   type   VARCHAR(250)
# 22               relation    VARCHAR(50)
# 23                  value        NUMERIC
# 24                  units   VARCHAR(100)
# 25             text_value  VARCHAR(1000)
# 26    standard_text_value  VARCHAR(1000)
# 27            action_type    VARCHAR(50)
#
# 📊 Columns in table `molecule_dictionary`:
#
#                     name           type
# 0               molregno         BIGINT
# 1              pref_name   VARCHAR(255)
# 2              chembl_id    VARCHAR(20)
# 3              max_phase  NUMERIC(2, 1)
# 4       therapeutic_flag       SMALLINT
# 5       dosed_ingredient       SMALLINT
# 6         structure_type    VARCHAR(10)
# 7           chebi_par_id         BIGINT
# 8          molecule_type    VARCHAR(30)
# 9         first_approval        INTEGER
# 10                  oral       SMALLINT
# 11            parenteral       SMALLINT
# 12               topical       SMALLINT
# 13     black_box_warning       SMALLINT
# 14       natural_product       SMALLINT
# 15        first_in_class       SMALLINT
# 16             chirality       SMALLINT
# 17               prodrug       SMALLINT
# 18        inorganic_flag       SMALLINT
# 19             usan_year        INTEGER
# 20     availability_type       SMALLINT
# 21             usan_stem    VARCHAR(50)
# 22          polymer_flag       SMALLINT
# 23          usan_substem    VARCHAR(50)
# 24  usan_stem_definition  VARCHAR(1000)
# 25      indication_class  VARCHAR(1000)
# 26        withdrawn_flag       SMALLINT
# 27        chemical_probe       SMALLINT
# 28                orphan       SMALLINT
#
# 📊 Columns in table `compound_structures`:
#
#                  name           type
# 0            molregno         BIGINT
# 1             molfile           TEXT
# 2      standard_inchi  VARCHAR(4000)
# 3  standard_inchi_key    VARCHAR(27)
# 4    canonical_smiles  VARCHAR(4000)
#
# 📊 Columns in table `target_dictionary`:
#
#                  name          type
# 0                 tid        BIGINT
# 1         target_type   VARCHAR(30)
# 2           pref_name  VARCHAR(200)
# 3              tax_id        BIGINT
# 4            organism  VARCHAR(150)
# 5           chembl_id   VARCHAR(20)
# 6  species_group_flag      SMALLINT
#
# 📊 Columns in table `drug_indication`:
#
#                 name           type
# 0         drugind_id         BIGINT
# 1          record_id         BIGINT
# 2           molregno         BIGINT
# 3  max_phase_for_ind  NUMERIC(2, 1)
# 4            mesh_id    VARCHAR(20)
# 5       mesh_heading   VARCHAR(200)
# 6             efo_id    VARCHAR(20)
# 7           efo_term   VARCHAR(200)
#
# 📊 Columns in table `assays`:
#
#                           name           type
# 0                     assay_id         BIGINT
# 1                       doc_id         BIGINT
# 2                  description  VARCHAR(4000)
# 3                   assay_type     VARCHAR(1)
# 4              assay_test_type    VARCHAR(20)
# 5               assay_category    VARCHAR(50)
# 6               assay_organism   VARCHAR(250)
# 7                 assay_tax_id         BIGINT
# 8                 assay_strain   VARCHAR(200)
# 9                 assay_tissue   VARCHAR(100)
# 10             assay_cell_type   VARCHAR(100)
# 11  assay_subcellular_fraction   VARCHAR(100)
# 12                         tid         BIGINT
# 13           relationship_type     VARCHAR(1)
# 14            confidence_score       SMALLINT
# 15                  curated_by    VARCHAR(32)
# 16                      src_id        INTEGER
# 17                src_assay_id    VARCHAR(50)
# 18                   chembl_id    VARCHAR(20)
# 19                     cell_id         BIGINT
# 20                  bao_format    VARCHAR(11)
# 21                   tissue_id         BIGINT
# 22                  variant_id         BIGINT
# 23                        aidx   VARCHAR(200)
# 24                 assay_group   VARCHAR(200)

# %%
query = """
SELECT 
    a.assay_id,
    a.molregno,
    md.chembl_id AS drug_id,
    md.pref_name AS drug_name,
    a.standard_type,
    a.standard_value,
    a.standard_units,
    a.standard_relation,
    ass.tid,
    td.pref_name AS target_name,
    td.organism AS target_organism
FROM activities a
JOIN molecule_dictionary md ON a.molregno = md.molregno
JOIN assays ass ON a.assay_id = ass.assay_id
JOIN target_dictionary td ON ass.tid = td.tid
WHERE a.standard_type IN ('IC50', 'Ki', 'Kd')
  AND a.standard_value IS NOT NULL
  AND a.standard_units = 'nM'
LIMIT 100;
"""
df_activity = pd.read_sql_query(query, conn)
df_activity.head()
# Out:
#    assay_id  molregno       drug_id drug_name standard_type  standard_value  \
# 0     54505    180094  CHEMBL113081      None          IC50        100000.0
# 1     83907    182268  CHEMBL324340      None          IC50          2500.0
# 2     88152    182268  CHEMBL324340      None          IC50         50000.0
# 3     83907    182855  CHEMBL109600      None          IC50          9000.0
# 4    154606    252199  CHEMBL357278      None          IC50          4000.0
#
#   standard_units standard_relation    tid                 target_name  \
# 0             nM                 >     63  DNA topoisomerase II alpha
# 1             nM                 =  11653                  Heparanase
# 2             nM                 >  22221          NON-PROTEIN TARGET
# 3             nM                 =  11653                  Heparanase
# 4             nM                 =  10483       Palmitoyl-CoA oxidase
#
#      target_organism
# 0       Homo sapiens
# 1       Homo sapiens
# 2               None
# 3       Homo sapiens
# 4  Rattus norvegicus

# %%
query = """
SELECT 
    md.chembl_id AS drug_id,
    cs.canonical_smiles
FROM molecule_dictionary md
JOIN compound_structures cs ON md.molregno = cs.molregno
WHERE cs.canonical_smiles IS NOT NULL
LIMIT 100;
"""
df_smiles = pd.read_sql_query(query, conn)
df_smiles.head()
# Out:
#         drug_id                                  canonical_smiles
# 0    CHEMBL6329      Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccccc1Cl
# 1    CHEMBL6328   Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(C#N)cc1
# 2  CHEMBL265667  Cc1cc(-n2ncc(=O)[nH]c2=O)cc(C)c1C(O)c1ccc(Cl)cc1
# 3    CHEMBL6362      Cc1ccc(C(=O)c2ccc(-n3ncc(=O)[nH]c3=O)cc2)cc1
# 4  CHEMBL267864    Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(Cl)cc1

# %%
query = """
SELECT 
    md.chembl_id AS drug_id,
    di.mesh_id,
    di.mesh_heading,
    di.efo_id,
    di.efo_term
FROM drug_indication di
JOIN molecule_dictionary md ON di.molregno = md.molregno
LIMIT 100;
"""
df_indications = pd.read_sql_query(query, conn)
df_indications.head()
# Out:
#          drug_id  mesh_id           mesh_heading       efo_id  \
# 0  CHEMBL1201823  D045743   Scleroderma, Diffuse  EFO:0000404
# 1  CHEMBL1201823  D001172  Arthritis, Rheumatoid  EFO:0000685
# 2  CHEMBL1201584  D009203  Myocardial Infarction  EFO:0000612
# 3   CHEMBL271227  D011471    Prostatic Neoplasms  EFO:0001663
# 4     CHEMBL1566  D003920      Diabetes Mellitus  EFO:0000400
#
#                 efo_term
# 0    diffuse scleroderma
# 1   rheumatoid arthritis
# 2  myocardial infarction
# 3     prostate carcinoma
# 4      diabetes mellitus

# %%
def show_columns(table_name):
    print(f"\n📊 Columns in `{table_name}`")
    query = f"PRAGMA table_info({table_name})"
    df = pd.read_sql_query(query, conn)
    display(df[['name', 'type']])

for table in [
    'compound_properties',
    'structural_alerts',
    'compound_structural_alerts',
    'structural_alert_sets',
    'drug_warning',
    'metabolism',
    'drug_mechanism'
]:
    show_columns(table)
# Out:
# 📊 Columns in `compound_properties`
#                            name            type
# 0                      molregno          BIGINT
# 1                   mw_freebase   NUMERIC(9, 2)
# 2                         alogp   NUMERIC(9, 2)
# 3                           hba         INTEGER
# 4                           hbd         INTEGER
# 5                           psa   NUMERIC(9, 2)
# 6                           rtb         INTEGER
# 7                      ro3_pass      VARCHAR(3)
# 8            num_ro5_violations        SMALLINT
# 9                  cx_most_apka   NUMERIC(9, 2)
# 10                 cx_most_bpka   NUMERIC(9, 2)
# 11                      cx_logp   NUMERIC(9, 2)
# 12                      cx_logd   NUMERIC(9, 2)
# 13            molecular_species     VARCHAR(50)
# 14                     full_mwt   NUMERIC(9, 2)
# 15               aromatic_rings         INTEGER
# 16                  heavy_atoms         INTEGER
# 17                 qed_weighted   NUMERIC(3, 2)
# 18              mw_monoisotopic  NUMERIC(11, 4)
# 19              full_molformula    VARCHAR(100)
# 20                 hba_lipinski         INTEGER
# 21                 hbd_lipinski         INTEGER
# 22  num_lipinski_ro5_violations        SMALLINT
# 23            np_likeness_score   NUMERIC(3, 2)
# 📊 Columns in `structural_alerts`
#            name           type
# 0      alert_id         BIGINT
# 1  alert_set_id         BIGINT
# 2    alert_name   VARCHAR(100)
# 3        smarts  VARCHAR(4000)
# 📊 Columns in `compound_structural_alerts`
#                name    type
# 0  cpd_str_alert_id  BIGINT
# 1          molregno  BIGINT
# 2          alert_id  BIGINT
# 📊 Columns in `structural_alert_sets`
#            name          type
# 0  alert_set_id        BIGINT
# 1      set_name  VARCHAR(100)
# 2      priority      SMALLINT
# 📊 Columns in `drug_warning`
#                         name           type
# 0                 warning_id         BIGINT
# 1                  record_id         BIGINT
# 2                   molregno         BIGINT
# 3               warning_type    VARCHAR(20)
# 4              warning_class   VARCHAR(100)
# 5        warning_description  VARCHAR(4000)
# 6            warning_country  VARCHAR(1000)
# 7               warning_year        INTEGER
# 8                   efo_term   VARCHAR(200)
# 9                     efo_id    VARCHAR(20)
# 10  efo_id_for_warning_class    VARCHAR(20)
# 📊 Columns in `metabolism`
#                     name           type
# 0                 met_id         BIGINT
# 1         drug_record_id         BIGINT
# 2    substrate_record_id         BIGINT
# 3   metabolite_record_id         BIGINT
# 4             pathway_id         BIGINT
# 5            pathway_key    VARCHAR(50)
# 6            enzyme_name   VARCHAR(200)
# 7             enzyme_tid         BIGINT
# 8         met_conversion   VARCHAR(200)
# 9               organism   VARCHAR(100)
# 10                tax_id         BIGINT
# 11           met_comment  VARCHAR(1000)
# 📊 Columns in `drug_mechanism`
#                     name           type
# 0                 mec_id         BIGINT
# 1              record_id         BIGINT
# 2               molregno         BIGINT
# 3    mechanism_of_action   VARCHAR(250)
# 4                    tid         BIGINT
# 5                site_id         BIGINT
# 6            action_type    VARCHAR(50)
# 7     direct_interaction       SMALLINT
# 8    molecular_mechanism       SMALLINT
# 9       disease_efficacy       SMALLINT
# 10     mechanism_comment  VARCHAR(2000)
# 11   selectivity_comment  VARCHAR(1000)
# 12  binding_site_comment  VARCHAR(1000)
# 13            variant_id         BIGINT

# %%
import pandas as pd

def get_table_columns(connection):
    tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
    tables = pd.read_sql_query(tables_query, connection)['name'].tolist()
    
    column_dict = {}
    for table in tables:
        try:
            cols = pd.read_sql_query(f"PRAGMA table_info({table});", connection)
            column_dict[table] = cols[['name', 'type']]
        except:
            column_dict[table] = 'Error reading columns'
    return column_dict

all_columns = get_table_columns(conn)

# Display results for verification
for table, cols in all_columns.items():
    print(f"\n📦 Table: {table}")
    print(cols)
# Out:
# 📦 Table: action_type
#           name          type
# 0  action_type   VARCHAR(50)
# 1  description  VARCHAR(200)
# 2  parent_type   VARCHAR(50)
#
# 📦 Table: assay_type
#          name          type
# 0  assay_type    VARCHAR(1)
# 1  assay_desc  VARCHAR(250)
#
# 📦 Table: chembl_id_lookup
#           name         type
# 0    chembl_id  VARCHAR(20)
# 1  entity_type  VARCHAR(50)
# 2    entity_id       BIGINT
# 3       status  VARCHAR(10)
# 4  last_active      INTEGER
#
# 📦 Table: confidence_score_lookup
#                name          type
# 0  confidence_score      SMALLINT
# 1       description  VARCHAR(100)
# 2    target_mapping   VARCHAR(30)
#
# 📦 Table: curation_lookup
#           name          type
# 0   curated_by   VARCHAR(32)
# 1  description  VARCHAR(100)
#
# 📦 Table: chembl_release
#                 name         type
# 0  chembl_release_id      INTEGER
# 1     chembl_release  VARCHAR(20)
# 2      creation_date     DATETIME
#
# 📦 Table: source
#               name           type
# 0           src_id        INTEGER
# 1  src_description   VARCHAR(500)
# 2   src_short_name    VARCHAR(20)
# 3      src_comment  VARCHAR(1200)
# 4          src_url   VARCHAR(200)
#
# 📦 Table: relationship_type
#                 name          type
# 0  relationship_type    VARCHAR(1)
# 1  relationship_desc  VARCHAR(250)
#
# 📦 Table: target_type
#           name          type
# 0  target_type   VARCHAR(30)
# 1  target_desc  VARCHAR(250)
# 2  parent_type   VARCHAR(25)
#
# 📦 Table: variant_sequences
#          name           type
# 0  variant_id         BIGINT
# 1    mutation  VARCHAR(2000)
# 2   accession    VARCHAR(25)
# 3     version         BIGINT
# 4     isoform         BIGINT
# 5    sequence           TEXT
# 6    organism   VARCHAR(200)
# 7      tax_id         BIGINT
#
# 📦 Table: bioassay_ontology
#      name          type
# 0  bao_id   VARCHAR(11)
# 1   label  VARCHAR(100)
#
# 📦 Table: data_validity_lookup
#                     name          type
# 0  data_validity_comment   VARCHAR(30)
# 1            description  VARCHAR(200)
#
# 📦 Table: activity_smid
#    name    type
# 0  smid  BIGINT
#
# 📦 Table: activity_stds_lookup
#                name             type
# 0        std_act_id           BIGINT
# 1     standard_type     VARCHAR(250)
# 2        definition     VARCHAR(500)
# 3    standard_units     VARCHAR(100)
# 4  normal_range_min  NUMERIC(24, 12)
# 5  normal_range_max  NUMERIC(24, 12)
#
# 📦 Table: assay_classification
#              name           type
# 0  assay_class_id         BIGINT
# 1              l1   VARCHAR(100)
# 2              l2   VARCHAR(100)
# 3              l3  VARCHAR(1000)
# 4      class_type    VARCHAR(50)
# 5          source    VARCHAR(50)
#
# 📦 Table: atc_classification
#                  name           type
# 0            who_name  VARCHAR(2000)
# 1              level1    VARCHAR(10)
# 2              level2    VARCHAR(10)
# 3              level3    VARCHAR(10)
# 4              level4    VARCHAR(10)
# 5              level5    VARCHAR(10)
# 6  level1_description  VARCHAR(2000)
# 7  level2_description  VARCHAR(2000)
# 8  level3_description  VARCHAR(2000)
# 9  level4_description  VARCHAR(2000)
#
# 📦 Table: bio_component_sequences
#               name          type
# 0     component_id        BIGINT
# 1   component_type   VARCHAR(50)
# 2      description  VARCHAR(200)
# 3         sequence          TEXT
# 4  sequence_md5sum   VARCHAR(32)
# 5           tax_id        BIGINT
# 6         organism  VARCHAR(150)
#
# 📦 Table: component_sequences
#               name          type
# 0     component_id        BIGINT
# 1   component_type   VARCHAR(50)
# 2        accession   VARCHAR(25)
# 3         sequence          TEXT
# 4  sequence_md5sum   VARCHAR(32)
# 5      description  VARCHAR(200)
# 6           tax_id        BIGINT
# 7         organism  VARCHAR(150)
# 8        db_source   VARCHAR(25)
# 9       db_version   VARCHAR(10)
#
# 📦 Table: protein_classification
#                  name           type
# 0    protein_class_id         BIGINT
# 1           parent_id         BIGINT
# 2           pref_name   VARCHAR(500)
# 3          short_name    VARCHAR(50)
# 4  protein_class_desc   VARCHAR(410)
# 5          definition  VARCHAR(4000)
# 6         class_level         BIGINT
#
# 📦 Table: domains
#                  name          type
# 0           domain_id        BIGINT
# 1         domain_type   VARCHAR(20)
# 2    source_domain_id   VARCHAR(20)
# 3         domain_name  VARCHAR(100)
# 4  domain_description  VARCHAR(500)
#
# 📦 Table: go_classification
#            name           type
# 0         go_id    VARCHAR(10)
# 1  parent_go_id    VARCHAR(10)
# 2     pref_name   VARCHAR(200)
# 3   class_level       SMALLINT
# 4        aspect     VARCHAR(1)
# 5          path  VARCHAR(1000)
#
# 📦 Table: structural_alert_sets
#            name          type
# 0  alert_set_id        BIGINT
# 1      set_name  VARCHAR(100)
# 2      priority      SMALLINT
#
# 📦 Table: products
#                    name          type
# 0           dosage_form  VARCHAR(200)
# 1                 route  VARCHAR(200)
# 2            trade_name  VARCHAR(200)
# 3         approval_date      DATETIME
# 4               ad_type    VARCHAR(5)
# 5                  oral      SMALLINT
# 6               topical      SMALLINT
# 7            parenteral      SMALLINT
# 8     black_box_warning      SMALLINT
# 9   applicant_full_name  VARCHAR(200)
# 10    innovator_company      SMALLINT
# 11           product_id   VARCHAR(30)
# 12             nda_type   VARCHAR(10)
#
# 📦 Table: frac_classification
#                   name           type
# 0        frac_class_id         BIGINT
# 1    active_ingredient   VARCHAR(500)
# 2               level1     VARCHAR(2)
# 3   level1_description  VARCHAR(2000)
# 4               level2     VARCHAR(2)
# 5   level2_description  VARCHAR(2000)
# 6               level3     VARCHAR(6)
# 7   level3_description  VARCHAR(2000)
# 8               level4     VARCHAR(7)
# 9   level4_description  VARCHAR(2000)
# 10              level5     VARCHAR(8)
# 11           frac_code     VARCHAR(4)
#
# 📦 Table: hrac_classification
#                  name           type
# 0       hrac_class_id         BIGINT
# 1   active_ingredient   VARCHAR(500)
# 2              level1     VARCHAR(2)
# 3  level1_description  VARCHAR(2000)
# 4              level2     VARCHAR(3)
# 5  level2_description  VARCHAR(2000)
# 6              level3     VARCHAR(5)
# 7           hrac_code     VARCHAR(2)
#
# 📦 Table: irac_classification
#                  name           type
# 0       irac_class_id         BIGINT
# 1   active_ingredient   VARCHAR(500)
# 2              level1     VARCHAR(1)
# 3  level1_description  VARCHAR(2000)
# 4              level2     VARCHAR(3)
# 5  level2_description  VARCHAR(2000)
# 6              level3     VARCHAR(6)
# 7  level3_description  VARCHAR(2000)
# 8              level4     VARCHAR(8)
# 9           irac_code     VARCHAR(3)
#
# 📦 Table: research_stem
#             name         type
# 0    res_stem_id       BIGINT
# 1  research_stem  VARCHAR(20)
#
# 📦 Table: organism_class
#      name          type
# 0   oc_id        BIGINT
# 1  tax_id        BIGINT
# 2      l1  VARCHAR(200)
# 3      l2  VARCHAR(200)
# 4      l3  VARCHAR(200)
#
# 📦 Table: patent_use_codes
#               name          type
# 0  patent_use_code    VARCHAR(8)
# 1       definition  VARCHAR(500)
#
# 📦 Table: usan_stems
#            name           type
# 0  usan_stem_id         BIGINT
# 1          stem   VARCHAR(100)
# 2      subgroup   VARCHAR(100)
# 3    annotation  VARCHAR(2000)
# 4    stem_class   VARCHAR(100)
# 5   major_class   VARCHAR(100)
#
# 📦 Table: version
#             name           type
# 0           name    VARCHAR(50)
# 1  creation_date       DATETIME
# 2       comments  VARCHAR(2000)
#
# 📦 Table: cell_dictionary
#                     name          type
# 0                cell_id        BIGINT
# 1              cell_name   VARCHAR(50)
# 2       cell_description  VARCHAR(200)
# 3     cell_source_tissue   VARCHAR(50)
# 4   cell_source_organism  VARCHAR(150)
# 5     cell_source_tax_id        BIGINT
# 6                 clo_id   VARCHAR(11)
# 7                 efo_id   VARCHAR(12)
# 8         cellosaurus_id   VARCHAR(15)
# 9            cl_lincs_id    VARCHAR(8)
# 10             chembl_id   VARCHAR(20)
# 11      cell_ontology_id   VARCHAR(10)
#
# 📦 Table: docs
#                  name           type
# 0              doc_id         BIGINT
# 1             journal    VARCHAR(50)
# 2                year        INTEGER
# 3              volume    VARCHAR(50)
# 4               issue    VARCHAR(50)
# 5          first_page    VARCHAR(50)
# 6           last_page    VARCHAR(50)
# 7           pubmed_id         BIGINT
# 8                 doi   VARCHAR(100)
# 9           chembl_id    VARCHAR(20)
# 10              title   VARCHAR(500)
# 11           doc_type    VARCHAR(50)
# 12            authors  VARCHAR(4000)
# 13           abstract           TEXT
# 14          patent_id    VARCHAR(20)
# 15               ridx   VARCHAR(200)
# 16             src_id        INTEGER
# 17  chembl_release_id        INTEGER
# 18            contact   VARCHAR(200)
#
# 📦 Table: target_dictionary
#                  name          type
# 0                 tid        BIGINT
# 1         target_type   VARCHAR(30)
# 2           pref_name  VARCHAR(200)
# 3              tax_id        BIGINT
# 4            organism  VARCHAR(150)
# 5           chembl_id   VARCHAR(20)
# 6  species_group_flag      SMALLINT
#
# 📦 Table: tissue_dictionary
#         name          type
# 0  tissue_id        BIGINT
# 1  uberon_id   VARCHAR(15)
# 2  pref_name  VARCHAR(200)
# 3     efo_id   VARCHAR(20)
# 4  chembl_id   VARCHAR(20)
# 5     bto_id   VARCHAR(20)
# 6  caloha_id    VARCHAR(7)
#
# 📦 Table: molecule_dictionary
#                     name           type
# 0               molregno         BIGINT
# 1              pref_name   VARCHAR(255)
# 2              chembl_id    VARCHAR(20)
# 3              max_phase  NUMERIC(2, 1)
# 4       therapeutic_flag       SMALLINT
# 5       dosed_ingredient       SMALLINT
# 6         structure_type    VARCHAR(10)
# 7           chebi_par_id         BIGINT
# 8          molecule_type    VARCHAR(30)
# 9         first_approval        INTEGER
# 10                  oral       SMALLINT
# 11            parenteral       SMALLINT
# 12               topical       SMALLINT
# 13     black_box_warning       SMALLINT
# 14       natural_product       SMALLINT
# 15        first_in_class       SMALLINT
# 16             chirality       SMALLINT
# 17               prodrug       SMALLINT
# 18        inorganic_flag       SMALLINT
# 19             usan_year        INTEGER
# 20     availability_type       SMALLINT
# 21             usan_stem    VARCHAR(50)
# 22          polymer_flag       SMALLINT
# 23          usan_substem    VARCHAR(50)
# 24  usan_stem_definition  VARCHAR(1000)
# 25      indication_class  VARCHAR(1000)
# 26        withdrawn_flag       SMALLINT
# 27        chemical_probe       SMALLINT
# 28                orphan       SMALLINT
#
# 📦 Table: activity_supp
#                    name           type
# 0                 as_id         BIGINT
# 1                  rgid         BIGINT
# 2                  smid         BIGINT
# 3                  type   VARCHAR(250)
# 4              relation    VARCHAR(50)
# 5                 value        NUMERIC
# 6                 units   VARCHAR(100)
# 7            text_value  VARCHAR(1000)
# 8         standard_type   VARCHAR(250)
# 9     standard_relation    VARCHAR(50)
# 10       standard_value        NUMERIC
# 11       standard_units   VARCHAR(100)
# 12  standard_text_value  VARCHAR(1000)
# 13             comments  VARCHAR(4000)
#
# 📦 Table: component_class
#                name    type
# 0      component_id  BIGINT
# 1  protein_class_id  BIGINT
# 2     comp_class_id  BIGINT
#
# 📦 Table: component_domains
#              name    type
# 0        compd_id  BIGINT
# 1       domain_id  BIGINT
# 2    component_id  BIGINT
# 3  start_position  BIGINT
# 4    end_position  BIGINT
#
# 📦 Table: component_go
#            name         type
# 0    comp_go_id       BIGINT
# 1  component_id       BIGINT
# 2         go_id  VARCHAR(10)
#
# 📦 Table: component_synonyms
#                 name          type
# 0         compsyn_id        BIGINT
# 1       component_id        BIGINT
# 2  component_synonym  VARCHAR(500)
# 3           syn_type   VARCHAR(20)
#
# 📦 Table: structural_alerts
#            name           type
# 0      alert_id         BIGINT
# 1  alert_set_id         BIGINT
# 2    alert_name   VARCHAR(100)
# 3        smarts  VARCHAR(4000)
#
# 📦 Table: defined_daily_dose
#           name           type
# 0     atc_code    VARCHAR(10)
# 1    ddd_units   VARCHAR(200)
# 2     ddd_admr  VARCHAR(1000)
# 3  ddd_comment  VARCHAR(2000)
# 4       ddd_id         BIGINT
# 5    ddd_value        NUMERIC
#
# 📦 Table: product_patents
#                   name         type
# 0          prod_pat_id       BIGINT
# 1           product_id  VARCHAR(30)
# 2            patent_no  VARCHAR(20)
# 3   patent_expire_date     DATETIME
# 4  drug_substance_flag     SMALLINT
# 5    drug_product_flag     SMALLINT
# 6      patent_use_code  VARCHAR(10)
# 7          delist_flag     SMALLINT
# 8      submission_date     DATETIME
#
# 📦 Table: protein_class_synonyms
#                     name           type
# 0        protclasssyn_id         BIGINT
# 1       protein_class_id         BIGINT
# 2  protein_class_synonym  VARCHAR(1000)
# 3               syn_type    VARCHAR(20)
#
# 📦 Table: research_companies
#                name          type
# 0        co_stem_id        BIGINT
# 1       res_stem_id        BIGINT
# 2           company  VARCHAR(100)
# 3           country   VARCHAR(50)
# 4  previous_company  VARCHAR(100)
#
# 📦 Table: assays
#                           name           type
# 0                     assay_id         BIGINT
# 1                       doc_id         BIGINT
# 2                  description  VARCHAR(4000)
# 3                   assay_type     VARCHAR(1)
# 4              assay_test_type    VARCHAR(20)
# 5               assay_category    VARCHAR(50)
# 6               assay_organism   VARCHAR(250)
# 7                 assay_tax_id         BIGINT
# 8                 assay_strain   VARCHAR(200)
# 9                 assay_tissue   VARCHAR(100)
# 10             assay_cell_type   VARCHAR(100)
# 11  assay_subcellular_fraction   VARCHAR(100)
# 12                         tid         BIGINT
# 13           relationship_type     VARCHAR(1)
# 14            confidence_score       SMALLINT
# 15                  curated_by    VARCHAR(32)
# 16                      src_id        INTEGER
# 17                src_assay_id    VARCHAR(50)
# 18                   chembl_id    VARCHAR(20)
# 19                     cell_id         BIGINT
# 20                  bao_format    VARCHAR(11)
# 21                   tissue_id         BIGINT
# 22                  variant_id         BIGINT
# 23                        aidx   VARCHAR(200)
# 24                 assay_group   VARCHAR(200)
#
# 📦 Table: compound_records
#               name           type
# 0        record_id         BIGINT
# 1         molregno         BIGINT
# 2           doc_id         BIGINT
# 3     compound_key   VARCHAR(250)
# 4    compound_name  VARCHAR(4000)
# 5           src_id        INTEGER
# 6  src_compound_id   VARCHAR(150)
# 7             cidx   VARCHAR(200)
#
# 📦 Table: binding_sites
#         name          type
# 0    site_id        BIGINT
# 1  site_name  VARCHAR(200)
# 2        tid        BIGINT
#
# 📦 Table: biotherapeutics
#             name           type
# 0       molregno         BIGINT
# 1    description  VARCHAR(2000)
# 2  helm_notation  VARCHAR(4000)
#
# 📦 Table: compound_properties
#                            name            type
# 0                      molregno          BIGINT
# 1                   mw_freebase   NUMERIC(9, 2)
# 2                         alogp   NUMERIC(9, 2)
# 3                           hba         INTEGER
# 4                           hbd         INTEGER
# 5                           psa   NUMERIC(9, 2)
# 6                           rtb         INTEGER
# 7                      ro3_pass      VARCHAR(3)
# 8            num_ro5_violations        SMALLINT
# 9                  cx_most_apka   NUMERIC(9, 2)
# 10                 cx_most_bpka   NUMERIC(9, 2)
# 11                      cx_logp   NUMERIC(9, 2)
# 12                      cx_logd   NUMERIC(9, 2)
# 13            molecular_species     VARCHAR(50)
# 14                     full_mwt   NUMERIC(9, 2)
# 15               aromatic_rings         INTEGER
# 16                  heavy_atoms         INTEGER
# 17                 qed_weighted   NUMERIC(3, 2)
# 18              mw_monoisotopic  NUMERIC(11, 4)
# 19              full_molformula    VARCHAR(100)
# 20                 hba_lipinski         INTEGER
# 21                 hbd_lipinski         INTEGER
# 22  num_lipinski_ro5_violations        SMALLINT
# 23            np_likeness_score   NUMERIC(3, 2)
#
# 📦 Table: compound_structural_alerts
#                name    type
# 0  cpd_str_alert_id  BIGINT
# 1          molregno  BIGINT
# 2          alert_id  BIGINT
#
# 📦 Table: compound_structures
#                  name           type
# 0            molregno         BIGINT
# 1             molfile           TEXT
# 2      standard_inchi  VARCHAR(4000)
# 3  standard_inchi_key    VARCHAR(27)
# 4    canonical_smiles  VARCHAR(4000)
#
# 📦 Table: molecule_atc_classification
#          name         type
# 0  mol_atc_id       BIGINT
# 1      level5  VARCHAR(10)
# 2    molregno       BIGINT
#
# 📦 Table: molecule_frac_classification
#             name    type
# 0    mol_frac_id  BIGINT
# 1  frac_class_id  BIGINT
# 2       molregno  BIGINT
#
# 📦 Table: molecule_hierarchy
#               name    type
# 0         molregno  BIGINT
# 1  parent_molregno  BIGINT
# 2  active_molregno  BIGINT
#
# 📦 Table: molecule_hrac_classification
#             name    type
# 0    mol_hrac_id  BIGINT
# 1  hrac_class_id  BIGINT
# 2       molregno  BIGINT
#
# 📦 Table: molecule_irac_classification
#             name    type
# 0    mol_irac_id  BIGINT
# 1  irac_class_id  BIGINT
# 2       molregno  BIGINT
#
# 📦 Table: molecule_synonyms
#           name          type
# 0     molregno        BIGINT
# 1     syn_type   VARCHAR(50)
# 2    molsyn_id        BIGINT
# 3  res_stem_id        BIGINT
# 4     synonyms  VARCHAR(250)
#
# 📦 Table: target_components
#            name      type
# 0           tid    BIGINT
# 1  component_id    BIGINT
# 2   targcomp_id    BIGINT
# 3     homologue  SMALLINT
#
# 📦 Table: target_relations
#            name         type
# 0           tid       BIGINT
# 1  relationship  VARCHAR(20)
# 2   related_tid       BIGINT
# 3    targrel_id       BIGINT
#
# 📦 Table: activities
#                      name           type
# 0             activity_id         BIGINT
# 1                assay_id         BIGINT
# 2                  doc_id         BIGINT
# 3               record_id         BIGINT
# 4                molregno         BIGINT
# 5       standard_relation    VARCHAR(50)
# 6          standard_value        NUMERIC
# 7          standard_units   VARCHAR(100)
# 8           standard_flag       SMALLINT
# 9           standard_type   VARCHAR(250)
# 10       activity_comment  VARCHAR(4000)
# 11  data_validity_comment    VARCHAR(30)
# 12    potential_duplicate       SMALLINT
# 13          pchembl_value  NUMERIC(4, 2)
# 14           bao_endpoint    VARCHAR(11)
# 15               uo_units    VARCHAR(10)
# 16             qudt_units    VARCHAR(70)
# 17                   toid        INTEGER
# 18            upper_value        NUMERIC
# 19   standard_upper_value        NUMERIC
# 20                 src_id        INTEGER
# 21                   type   VARCHAR(250)
# 22               relation    VARCHAR(50)
# 23                  value        NUMERIC
# 24                  units   VARCHAR(100)
# 25             text_value  VARCHAR(1000)
# 26    standard_text_value  VARCHAR(1000)
# 27            action_type    VARCHAR(50)
#
# 📦 Table: assay_class_map
#              name    type
# 0  ass_cls_map_id  BIGINT
# 1        assay_id  BIGINT
# 2  assay_class_id  BIGINT
#
# 📦 Table: assay_parameters
#                    name           type
# 0        assay_param_id         BIGINT
# 1              assay_id         BIGINT
# 2                  type   VARCHAR(250)
# 3              relation    VARCHAR(50)
# 4                 value        NUMERIC
# 5                 units   VARCHAR(100)
# 6            text_value  VARCHAR(4000)
# 7         standard_type   VARCHAR(250)
# 8     standard_relation    VARCHAR(50)
# 9        standard_value        NUMERIC
# 10       standard_units   VARCHAR(100)
# 11  standard_text_value  VARCHAR(4000)
# 12             comments  VARCHAR(4000)
#
# 📦 Table: biotherapeutic_components
#            name    type
# 0    biocomp_id  BIGINT
# 1      molregno  BIGINT
# 2  component_id  BIGINT
#
# 📦 Table: drug_indication
#                 name           type
# 0         drugind_id         BIGINT
# 1          record_id         BIGINT
# 2           molregno         BIGINT
# 3  max_phase_for_ind  NUMERIC(2, 1)
# 4            mesh_id    VARCHAR(20)
# 5       mesh_heading   VARCHAR(200)
# 6             efo_id    VARCHAR(20)
# 7           efo_term   VARCHAR(200)
#
# 📦 Table: drug_mechanism
#                     name           type
# 0                 mec_id         BIGINT
# 1              record_id         BIGINT
# 2               molregno         BIGINT
# 3    mechanism_of_action   VARCHAR(250)
# 4                    tid         BIGINT
# 5                site_id         BIGINT
# 6            action_type    VARCHAR(50)
# 7     direct_interaction       SMALLINT
# 8    molecular_mechanism       SMALLINT
# 9       disease_efficacy       SMALLINT
# 10     mechanism_comment  VARCHAR(2000)
# 11   selectivity_comment  VARCHAR(1000)
# 12  binding_site_comment  VARCHAR(1000)
# 13            variant_id         BIGINT
#
# 📦 Table: drug_warning
#                         name           type
# 0                 warning_id         BIGINT
# 1                  record_id         BIGINT
# 2                   molregno         BIGINT
# 3               warning_type    VARCHAR(20)
# 4              warning_class   VARCHAR(100)
# 5        warning_description  VARCHAR(4000)
# 6            warning_country  VARCHAR(1000)
# 7               warning_year        INTEGER
# 8                   efo_term   VARCHAR(200)
# 9                     efo_id    VARCHAR(20)
# 10  efo_id_for_warning_class    VARCHAR(20)
#
# 📦 Table: formulations
#              name          type
# 0      product_id   VARCHAR(30)
# 1      ingredient  VARCHAR(200)
# 2        strength  VARCHAR(300)
# 3       record_id        BIGINT
# 4        molregno        BIGINT
# 5  formulation_id        BIGINT
#
# 📦 Table: metabolism
#                     name           type
# 0                 met_id         BIGINT
# 1         drug_record_id         BIGINT
# 2    substrate_record_id         BIGINT
# 3   metabolite_record_id         BIGINT
# 4             pathway_id         BIGINT
# 5            pathway_key    VARCHAR(50)
# 6            enzyme_name   VARCHAR(200)
# 7             enzyme_tid         BIGINT
# 8         met_conversion   VARCHAR(200)
# 9               organism   VARCHAR(100)
# 10                tax_id         BIGINT
# 11           met_comment  VARCHAR(1000)
#
# 📦 Table: site_components
#             name           type
# 0    sitecomp_id         BIGINT
# 1        site_id         BIGINT
# 2   component_id         BIGINT
# 3      domain_id         BIGINT
# 4  site_residues  VARCHAR(2000)
#
# 📦 Table: activity_properties
#                    name           type
# 0                 ap_id         BIGINT
# 1           activity_id         BIGINT
# 2                  type   VARCHAR(250)
# 3              relation    VARCHAR(50)
# 4                 value        NUMERIC
# 5                 units   VARCHAR(100)
# 6            text_value  VARCHAR(2000)
# 7         standard_type   VARCHAR(250)
# 8     standard_relation    VARCHAR(50)
# 9        standard_value        NUMERIC
# 10       standard_units   VARCHAR(100)
# 11  standard_text_value  VARCHAR(2000)
# 12             comments  VARCHAR(2000)
# 13          result_flag       SMALLINT
#
# 📦 Table: activity_supp_map
#           name    type
# 0     actsm_id  BIGINT
# 1  activity_id  BIGINT
# 2         smid  BIGINT
#
# 📦 Table: indication_refs
#          name           type
# 0   indref_id         BIGINT
# 1  drugind_id         BIGINT
# 2    ref_type    VARCHAR(50)
# 3      ref_id  VARCHAR(4000)
# 4     ref_url  VARCHAR(4000)
#
# 📦 Table: ligand_eff
#           name           type
# 0  activity_id         BIGINT
# 1          bei  NUMERIC(9, 2)
# 2          sei  NUMERIC(9, 2)
# 3           le  NUMERIC(9, 2)
# 4          lle  NUMERIC(9, 2)
#
# 📦 Table: mechanism_refs
#         name          type
# 0  mecref_id        BIGINT
# 1     mec_id        BIGINT
# 2   ref_type   VARCHAR(50)
# 3     ref_id  VARCHAR(200)
# 4    ref_url  VARCHAR(400)
#
# 📦 Table: metabolism_refs
#         name          type
# 0  metref_id        BIGINT
# 1     met_id        BIGINT
# 2   ref_type   VARCHAR(50)
# 3     ref_id  VARCHAR(200)
# 4    ref_url  VARCHAR(400)
#
# 📦 Table: predicted_binding_domains
#                 name         type
# 0        predbind_id       BIGINT
# 1        activity_id       BIGINT
# 2            site_id       BIGINT
# 3  prediction_method  VARCHAR(50)
# 4         confidence  VARCHAR(10)
#
# 📦 Table: warning_refs
#          name           type
# 0  warnref_id         BIGINT
# 1  warning_id         BIGINT
# 2    ref_type    VARCHAR(50)
# 3      ref_id  VARCHAR(4000)
# 4     ref_url  VARCHAR(4000)
#
# 📦 Table: sqlite_stat1
#    name type
# 0   tbl
# 1   idx
# 2  stat

# %%
# !pip install tdqm
# Out:
# Collecting tdqm
#   Downloading tdqm-0.0.1.tar.gz (1.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from tdqm) (4.66.5)
# Requirement already satisfied: colorama in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from tqdm->tdqm) (0.4.6)
# Building wheels for collected packages: tdqm
#   Building wheel for tdqm (setup.py): started
#   Building wheel for tdqm (setup.py): finished with status 'done'
#   Created wheel for tdqm: filename=tdqm-0.0.1-py3-none-any.whl size=1395 sha256=5191731ad923de20eb37a12f5f25c2b923479d11aab233cd2e1168dc996bd3bc
#   Stored in directory: c:\users\konde\appdata\local\pip\cache\wheels\af\02\71\aae0f7ee738abf19498353918ddae0f90a0d6ceb337b0bbc91
# Successfully built tdqm
# Installing collected packages: tdqm
# Successfully installed tdqm-0.0.1
#   DEPRECATION: Building 'tdqm' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'tdqm'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import sqlite3
import pandas as pd
import time
from tqdm import tqdm

start_total = time.time()

print("🔌 Connecting to database...")
conn = sqlite3.connect("chembl_35/chembl_35_sqlite/chembl_35.db")

print("🔍 Step 1: Running TEST query with LIMIT 50000...")
start = time.time()
query = """
SELECT 
    md.chembl_id AS drug_id,
    cs.canonical_smiles AS SMILES,
    cp.cx_logd AS logD,
    cp.qed_weighted AS drug_likeness,
    cp.psa AS psa,
    cp.cx_logp AS logP,
    act.standard_value AS IC50,
    td.pref_name AS target,
    di.efo_term AS indication,
    sa.alert_name AS toxicity_alert,
    dw.warning_description AS warning,
    met.enzyme_name AS metabolism_enzyme,
    met.met_conversion AS metabolism_conversion

FROM molecule_dictionary md
JOIN compound_structures cs ON md.molregno = cs.molregno
JOIN compound_properties cp ON md.molregno = cp.molregno
JOIN activities act ON md.molregno = act.molregno AND act.standard_type = 'IC50' AND act.standard_value IS NOT NULL
JOIN assays a ON act.assay_id = a.assay_id AND a.confidence_score >= 8
JOIN target_dictionary td ON a.tid = td.tid
LEFT JOIN drug_indication di ON md.molregno = di.molregno
LEFT JOIN compound_structural_alerts csa ON md.molregno = csa.molregno
LEFT JOIN structural_alerts sa ON csa.alert_id = sa.alert_id
LEFT JOIN drug_warning dw ON md.molregno = dw.molregno
LEFT JOIN compound_records cr ON md.molregno = cr.molregno
LEFT JOIN metabolism met ON cr.record_id = met.substrate_record_id

LIMIT 50000
"""

df = pd.read_sql_query(query, conn)
conn.close()
print(f"✅ Query finished in {round(time.time() - start, 2)} seconds")
print(f"🔢 Rows fetched: {len(df):,}")

# Step 2: Cleaning
print("🧹 Step 2: Cleaning...")
start = time.time()
df.dropna(subset=["SMILES", "IC50", "target"], inplace=True)
df.drop_duplicates(inplace=True)
df["IC50"] = pd.to_numeric(df["IC50"], errors="coerce")
print(f"✅ Cleaned in {round(time.time() - start, 2)} seconds")

# Step 3: Save to CSV + Parquet
print("💾 Step 3: Saving to disk...")
start = time.time()

# CSV with tqdm
with tqdm(total=len(df), desc="Saving CSV", unit="rows") as pbar:
    df.to_csv("test_clean_chembl.csv", index=False)
    pbar.update(len(df))

# Parquet (fast!)
df.to_parquet("test_clean_chembl.parquet", index=False)
print(f"✅ Saved CSV + Parquet in {round(time.time() - start, 2)} seconds")

print(f"🏁 ALL DONE in {round(time.time() - start_total, 2)} seconds")
# Out:
# 🔌 Connecting to database...
# 🔍 Step 1: Running TEST query with LIMIT 50000...
# ✅ Query finished in 2.01 seconds
# 🔢 Rows fetched: 50,000
# 🧹 Step 2: Cleaning...
# ✅ Cleaned in 0.09 seconds
# 💾 Step 3: Saving to disk...
# Saving CSV: 100%|█████████████████████████████████████████████████████████████| 1871/1871 [00:00<00:00, 42983.98rows/s]
# ✅ Saved CSV + Parquet in 0.91 seconds
# 🏁 ALL DONE in 3.01 seconds

# %%
import pandas as pd
import numpy as np
# Load dataset (choose either CSV or Parquet)
df = pd.read_csv("test_clean_chembl.csv")  # OR
# df = pd.read_parquet("test_clean_chembl.parquet")

# 🔍 Preview top rows
print("🔹 Preview:")
print(df.head())

# 📊 Summary info
print("\n🔹 Data Info:")
print(df.info())

# 🧼 Missing values check
print("\n🔹 Null Values:")
print(df.isnull().sum())

# 🔢 Unique targets and indications
print("\n🔹 Unique targets:", df['target'].nunique())
print("🔹 Unique indications:", df['indication'].nunique())

# 📈 IC50 distribution
print("\n🔹 IC50 (nM) stats:")
print(df['IC50'].describe())

# 📊 Most common targets
print("\n🔹 Top 10 Targets:")
print(df['target'].value_counts().head(10))

# 🧪 Optional: Convert IC50 to pIC50 (–log10(IC50 in molar units))
df["pIC50"] = -df["IC50"].astype(float).div(1e9).apply(lambda x: np.log10(x) if x > 0 else None)

# 🎯 Filter: Only rows targeting EGFR
egfr_df = df[df["target"].str.contains("EGFR", na=False)]
print("\n🔍 Drugs targeting EGFR:")
print(egfr_df[["drug_id", "SMILES", "IC50", "indication"]].head())
# Out:
# 🔹 Preview:
#         drug_id                                             SMILES  logD  \
# 0  CHEMBL113081           c1ccc(-c2nc3c(-c4nc5ccccc5o4)cccc3o2)cc1  4.72
# 1  CHEMBL324340  Cc1ccc2oc(-c3cccc(N4C(=O)c5ccc(C(=O)O)cc5C4=O)...  0.74
# 2  CHEMBL109600  COc1ccccc1-c1ccc2oc(-c3ccc(OC)c(N4C(=O)c5ccc(C...  1.56
# 3  CHEMBL357278  Cc1nc2cc(OC[C@H](O)CN3CCN(CC(=O)Nc4ccc(Cl)c(C(...  3.62
# 4  CHEMBL357119  Cc1nc2cc(OC[C@H](O)CN3CCN(CC(=O)NCCc4ccccc4)CC...  2.12
#
#    drug_likeness     psa  logP      IC50                      target  \
# 0           0.44   52.06  4.72  100000.0  DNA topoisomerase II alpha
# 1           0.52  100.71  4.12    2500.0                  Heparanase
# 2           0.28  119.17  4.94    9000.0                  Heparanase
# 3           0.44   77.93  3.71    4000.0       Palmitoyl-CoA oxidase
# 4           0.48   77.93  2.22   17000.0       Palmitoyl-CoA oxidase
#
#   indication toxicity_alert  warning metabolism_enzyme metabolism_conversion
# 0        NaN            NaN      NaN               NaN                   NaN
# 1        NaN    phthalimide      NaN               NaN                   NaN
# 2        NaN    phthalimide      NaN               NaN                   NaN
# 3        NaN            NaN      NaN               NaN                   NaN
# 4        NaN            NaN      NaN               NaN                   NaN
#
# 🔹 Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1871 entries, 0 to 1870
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   drug_id                1871 non-null   object
#  1   SMILES                 1871 non-null   object
#  2   logD                   1864 non-null   float64
#  3   drug_likeness          1864 non-null   float64
#  4   psa                    1864 non-null   float64
#  5   logP                   1864 non-null   float64
#  6   IC50                   1871 non-null   float64
#  7   target                 1871 non-null   object
#  8   indication             186 non-null    object
#  9   toxicity_alert         1558 non-null   object
#  10  warning                0 non-null      float64
#  11  metabolism_enzyme      1 non-null      object
#  12  metabolism_conversion  75 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 190.2+ KB
# None
#
# 🔹 Null Values:
# drug_id                     0
# SMILES                      0
# logD                        7
# drug_likeness               7
# psa                         7
# logP                        7
# IC50                        0
# target                      0
# indication               1685
# toxicity_alert            313
# warning                  1871
# metabolism_enzyme        1870
# metabolism_conversion    1796
# dtype: int64
#
# 🔹 Unique targets: 147
# 🔹 Unique indications: 52
#
# 🔹 IC50 (nM) stats:
# count    1.871000e+03
# mean     8.184043e+04
# std      4.477809e+05
# min      1.000000e-02
# 25%      1.700000e+01
# 50%      4.160000e+02
# 75%      9.100000e+03
# max      1.200000e+07
# Name: IC50, dtype: float64
#
# 🔹 Top 10 Targets:
# target
# Epidermal growth factor receptor erbB1          109
# Cyclooxygenase-2                                109
# Phospholipase A2 group 1B                        67
# Matrix metalloproteinase 3                       57
# Matrix metalloproteinase-2                       48
# Renin                                            46
# Matrix metalloproteinase-1                       42
# Matrix metalloproteinase 13                      42
# ADAM17                                           40
# Human immunodeficiency virus type 1 protease     40
# Name: count, dtype: int64
#
# 🔍 Drugs targeting EGFR:
# Empty DataFrame
# Columns: [drug_id, SMILES, IC50, indication]
# Index: []

# %%
egfr_df = df[df["target"].str.contains("epidermal growth factor", case=False, na=False)]

# %%
# Keep rows with non-null SMILES, IC50, and indication
filtered_df = df.dropna(subset=["SMILES", "IC50", "indication"])
print(f"✅ Rows with all critical data: {len(filtered_df)}")
# Out:
# ✅ Rows with all critical data: 186

# %%
import numpy as np
df["pIC50"] = -df["IC50"].div(1e9).apply(lambda x: np.log10(x) if x > 0 else None)
strong_binders = df[df["pIC50"] > 7]
strong_binders.to_csv("strong_binders.csv", index=False)

# %%
df1 = pd.read_csv("strong_binders.csv")
df1.head()
# Out:
#         drug_id                                      SMILES  logD  \
# 0  CHEMBL305153  CC(C)(C)NC[C@H](O)CON=C1c2ccccc2-c2ccccc21  1.08
# 1  CHEMBL305153  CC(C)(C)NC[C@H](O)CON=C1c2ccccc2-c2ccccc21  1.08
# 2  CHEMBL305153  CC(C)(C)NC[C@H](O)CON=C1c2ccccc2-c2ccccc21  1.08
# 3  CHEMBL305153  CC(C)(C)NC[C@H](O)CON=C1c2ccccc2-c2ccccc21  1.08
# 4  CHEMBL305153  CC(C)(C)NC[C@H](O)CON=C1c2ccccc2-c2ccccc21  1.08
#
#    drug_likeness    psa  logP  IC50                      target indication  \
# 0           0.71  53.85  3.55  29.4  Beta-1 adrenergic receptor        NaN
# 1           0.71  53.85  3.55  29.4  Beta-1 adrenergic receptor        NaN
# 2           0.71  53.85  3.55  29.4  Beta-1 adrenergic receptor        NaN
# 3           0.71  53.85  3.55  30.8  Beta-2 adrenergic receptor        NaN
# 4           0.71  53.85  3.55  30.8  Beta-2 adrenergic receptor        NaN
#
#                 toxicity_alert  warning  metabolism_enzyme  \
# 0                        imine      NaN                NaN
# 1  Oxygen-nitrogen single bond      NaN                NaN
# 2         Long aliphatic chain      NaN                NaN
# 3                        imine      NaN                NaN
# 4  Oxygen-nitrogen single bond      NaN                NaN
#
#   metabolism_conversion     pIC50
# 0                   NaN  7.531653
# 1                   NaN  7.531653
# 2                   NaN  7.531653
# 3                   NaN  7.511449
# 4                   NaN  7.511449

# %%
import pandas as pd
import sqlite3

# Connect to your ChEMBL SQLite database
conn = sqlite3.connect("chembl_35/chembl_35_sqlite/chembl_35.db")

# Define the solid SQL query
query = """
SELECT DISTINCT
    md.chembl_id                    AS drug_id,
    md.pref_name                    AS drug_name,
    cs.canonical_smiles             AS SMILES,
    cp.cx_logd                      AS logD,
    cp.cx_logp                      AS logP,
    cp.psa                          AS psa,
    cp.qed_weighted                 AS drug_likeness,
    md.max_phase                    AS max_phase,
    act.standard_value              AS IC50,
    td.pref_name                    AS target,
    td.organism                     AS organism,
    td.target_type                  AS target_type,
    dm.mechanism_of_action          AS mechanism_of_action,
    di.efo_term                     AS efo_term,
    di.efo_id                       AS efo_id,
    di.mesh_heading                 AS mesh_heading,
    di.mesh_id                      AS mesh_id,
    sa.alert_name                   AS toxicity_alert

FROM molecule_dictionary md
INNER JOIN compound_structures cs ON md.molregno = cs.molregno
INNER JOIN compound_properties cp ON md.molregno = cp.molregno
INNER JOIN activities act ON md.molregno = act.molregno
    AND act.standard_type = 'IC50'
    AND act.standard_value IS NOT NULL
INNER JOIN assays a ON act.assay_id = a.assay_id
    AND a.confidence_score >= 8
INNER JOIN target_dictionary td ON a.tid = td.tid
LEFT JOIN drug_mechanism dm ON md.molregno = dm.molregno AND dm.tid = td.tid
LEFT JOIN drug_indication di ON md.molregno = di.molregno
LEFT JOIN compound_structural_alerts csa ON md.molregno = csa.molregno
LEFT JOIN structural_alerts sa ON csa.alert_id = sa.alert_id
LIMIT 50000;
"""

# Run the query and load into DataFrame
df = pd.read_sql_query(query, conn)

# Clean: drop any rows with NULL SMILES or IC50 just in case
df.dropna(subset=["SMILES", "IC50"], inplace=True)

# Convert IC50 to pIC50 (optional)
import numpy as np
df["pIC50"] = -df["IC50"].astype(float).div(1e9).apply(lambda x: np.log10(x) if x > 0 else None)

# Preview
df.head()
# Out:
#         drug_id drug_name                                             SMILES  \
# 0  CHEMBL113081      None           c1ccc(-c2nc3c(-c4nc5ccccc5o4)cccc3o2)cc1
# 1  CHEMBL324340      None  Cc1ccc2oc(-c3cccc(N4C(=O)c5ccc(C(=O)O)cc5C4=O)...
# 2  CHEMBL109600      None  COc1ccccc1-c1ccc2oc(-c3ccc(OC)c(N4C(=O)c5ccc(C...
# 3  CHEMBL357278      None  Cc1nc2cc(OC[C@H](O)CN3CCN(CC(=O)Nc4ccc(Cl)c(C(...
# 4  CHEMBL357119      None  Cc1nc2cc(OC[C@H](O)CN3CCN(CC(=O)NCCc4ccccc4)CC...
#
#    logD  logP     psa  drug_likeness  max_phase      IC50  \
# 0  4.72  4.72   52.06           0.44        NaN  100000.0
# 1  0.74  4.12  100.71           0.52        NaN    2500.0
# 2  1.56  4.94  119.17           0.28        NaN    9000.0
# 3  3.62  3.71   77.93           0.44        NaN    4000.0
# 4  2.12  2.22   77.93           0.48        NaN   17000.0
#
#                        target           organism     target_type  \
# 0  DNA topoisomerase II alpha       Homo sapiens  SINGLE PROTEIN
# 1                  Heparanase       Homo sapiens  SINGLE PROTEIN
# 2                  Heparanase       Homo sapiens  SINGLE PROTEIN
# 3       Palmitoyl-CoA oxidase  Rattus norvegicus  SINGLE PROTEIN
# 4       Palmitoyl-CoA oxidase  Rattus norvegicus  SINGLE PROTEIN
#
#   mechanism_of_action efo_term efo_id mesh_heading mesh_id toxicity_alert  \
# 0                None     None   None         None    None           None
# 1                None     None   None         None    None    phthalimide
# 2                None     None   None         None    None    phthalimide
# 3                None     None   None         None    None           None
# 4                None     None   None         None    None           None
#
#       pIC50
# 0  4.000000
# 1  5.602060
# 2  5.045757
# 3  5.397940
# 4  4.769551

# %%
df = df[df["max_phase"] >= 2]             # Keep only clinical-stage drugs
df = df[df["mechanism_of_action"].notna()]  # Only drugs with known MoA
df = df[df["efo_term"].notna()]             # Keep drugs with disease linkage
df.head()
df.shape[0]
# Out:
# 3761

# %%
import pandas as pd
import sqlite3
import numpy as np

# Connect to your ChEMBL SQLite database
conn = sqlite3.connect("chembl_35/chembl_35_sqlite/chembl_35.db")

# Optimized SQL query (no LIMIT)
query = """
SELECT DISTINCT
    md.chembl_id                    AS drug_id,
    md.pref_name                    AS drug_name,
    cs.canonical_smiles             AS SMILES,
    cp.cx_logd                      AS logD,
    cp.cx_logp                      AS logP,
    cp.psa                          AS psa,
    cp.qed_weighted                 AS drug_likeness,
    md.max_phase                    AS max_phase,
    act.standard_value              AS IC50,
    td.pref_name                    AS target,
    td.organism                     AS organism,
    td.target_type                  AS target_type,
    dm.mechanism_of_action          AS mechanism_of_action,
    di.efo_term                     AS efo_term,
    di.efo_id                       AS efo_id,
    di.mesh_heading                 AS mesh_heading,
    di.mesh_id                      AS mesh_id,
    sa.alert_name                   AS toxicity_alert
FROM molecule_dictionary md
INNER JOIN compound_structures cs ON md.molregno = cs.molregno
INNER JOIN compound_properties cp ON md.molregno = cp.molregno
INNER JOIN activities act ON md.molregno = act.molregno
    AND act.standard_type = 'IC50'
    AND act.standard_value IS NOT NULL
INNER JOIN assays a ON act.assay_id = a.assay_id
    AND a.confidence_score >= 8
INNER JOIN target_dictionary td ON a.tid = td.tid
LEFT JOIN drug_mechanism dm ON md.molregno = dm.molregno AND dm.tid = td.tid
LEFT JOIN drug_indication di ON md.molregno = di.molregno
LEFT JOIN compound_structural_alerts csa ON md.molregno = csa.molregno
LEFT JOIN structural_alerts sa ON csa.alert_id = sa.alert_id
"""

# Run the query
print("🔄 Loading data...")
df = pd.read_sql_query(query, conn)

# Drop rows missing SMILES or IC50
df.dropna(subset=["SMILES", "IC50"], inplace=True)

# Filter to clinically relevant + annotated data
df = df[df["max_phase"] >= 2]
df = df[df["mechanism_of_action"].notna()]
df = df[df["efo_term"].notna()]

# Drop duplicates
df.drop_duplicates(inplace=True)

# Compute pIC50
df["pIC50"] = -df["IC50"].astype(float).div(1e9).apply(lambda x: np.log10(x) if x > 0 else None)

# Save to CSV (added line)
df.to_csv("cleaned_clinical_drugs_dataset.csv", index=False)

# Summary
print("✅ Final dataset shape:", df.shape)
print("🧪 Columns:", list(df.columns))
# Out:
# 🔄 Loading data...
# ✅ Final dataset shape: (553992, 19)
# 🧪 Columns: ['drug_id', 'drug_name', 'SMILES', 'logD', 'logP', 'psa', 'drug_likeness', 'max_phase', 'IC50', 'target', 'organism', 'target_type', 'mechanism_of_action', 'efo_term', 'efo_id', 'mesh_heading', 'mesh_id', 'toxicity_alert', 'pIC50']

# %%
df.head(30)
# Out:
#          drug_id   drug_name  \
# 0   CHEMBL223228   EFAVIRENZ
# 1   CHEMBL223228   EFAVIRENZ
# 2   CHEMBL223228   EFAVIRENZ
# 3   CHEMBL223228   EFAVIRENZ
# 4   CHEMBL223228   EFAVIRENZ
# 5   CHEMBL223228   EFAVIRENZ
# 6   CHEMBL223228   EFAVIRENZ
# 7   CHEMBL223228   EFAVIRENZ
# 8   CHEMBL223228   EFAVIRENZ
# 9   CHEMBL223228   EFAVIRENZ
# 10  CHEMBL223228   EFAVIRENZ
# 11  CHEMBL223228   EFAVIRENZ
# 12  CHEMBL223228   EFAVIRENZ
# 13  CHEMBL223228   EFAVIRENZ
# 14  CHEMBL223228   EFAVIRENZ
# 15      CHEMBL57  NEVIRAPINE
# 16      CHEMBL57  NEVIRAPINE
# 17      CHEMBL57  NEVIRAPINE
# 18      CHEMBL57  NEVIRAPINE
# 19      CHEMBL57  NEVIRAPINE
# 20      CHEMBL57  NEVIRAPINE
# 21      CHEMBL57  NEVIRAPINE
# 22      CHEMBL57  NEVIRAPINE
# 23      CHEMBL57  NEVIRAPINE
# 24      CHEMBL57  NEVIRAPINE
# 25      CHEMBL57  NEVIRAPINE
# 25                    Cc1ccnc2c1NC(=O)c1cccnc1N2C1CC1  2.49  2.49   58.12
# 26                    Cc1ccnc2c1NC(=O)c1cccnc1N2C1CC1  2.49  2.49   58.12
# 27  O=C(NO)C1(CS(=O)(=O)c2ccc(Oc3ccc(Cl)cc3)cc2)CC...  2.24  2.25  101.93
# 28  O=C(NO)C1(CS(=O)(=O)c2ccc(Oc3ccc(Cl)cc3)cc2)CC...  2.24  2.25  101.93
# 29  O=C(NO)C1(CS(=O)(=O)c2ccc(Oc3ccc(Cl)cc3)cc2)CC...  2.24  2.25  101.93
#
#     drug_likeness  max_phase      IC50  \
# 0            0.73        4.0      0.75
# 1            0.73        4.0      0.75
# 2            0.73        4.0      0.75
# 3            0.73        4.0      0.75
# 4            0.73        4.0      0.75
# 5            0.73        4.0      0.75
# 6            0.73        4.0      0.75
# 7            0.73        4.0      0.75
# 8            0.73        4.0      0.75
# 9            0.73        4.0      0.75
# 10           0.73        4.0      0.75
# 11           0.73        4.0      0.75
# 12           0.73        4.0      0.75
# 13           0.73        4.0      0.75
# 14           0.73        4.0      0.75
# 15           0.86        4.0  23000.00
# 16           0.86        4.0  23000.00
# 17           0.86        4.0  23000.00
# 18           0.86        4.0  23000.00
# 19           0.86        4.0  23000.00
# 20           0.86        4.0  23000.00
# 21           0.86        4.0    230.00
# 22           0.86        4.0    230.00
# 23           0.86        4.0    230.00
# 24           0.86        4.0    230.00
# 25           0.86        4.0    230.00
# 26           0.86        4.0    230.00
# 27           0.54        2.0      3.00
# 28           0.54        2.0      3.00
# 29           0.54        2.0      3.00
#
#                                                target  \
# 0   Human immunodeficiency virus type 1 reverse tr...
# 1   Human immunodeficiency virus type 1 reverse tr...
# 2   Human immunodeficiency virus type 1 reverse tr...
# 3   Human immunodeficiency virus type 1 reverse tr...
# 4   Human immunodeficiency virus type 1 reverse tr...
# 5   Human immunodeficiency virus type 1 reverse tr...
# 6   Human immunodeficiency virus type 1 reverse tr...
# 7   Human immunodeficiency virus type 1 reverse tr...
# 8   Human immunodeficiency virus type 1 reverse tr...
# 9   Human immunodeficiency virus type 1 reverse tr...
# 10  Human immunodeficiency virus type 1 reverse tr...
# 11  Human immunodeficiency virus type 1 reverse tr...
# 12  Human immunodeficiency virus type 1 reverse tr...
# 13  Human immunodeficiency virus type 1 reverse tr...
# 14  Human immunodeficiency virus type 1 reverse tr...
# 15  Human immunodeficiency virus type 1 reverse tr...
# 16  Human immunodeficiency virus type 1 reverse tr...
# 17  Human immunodeficiency virus type 1 reverse tr...
# 18  Human immunodeficiency virus type 1 reverse tr...
# 19  Human immunodeficiency virus type 1 reverse tr...
# 20  Human immunodeficiency virus type 1 reverse tr...
# 21  Human immunodeficiency virus type 1 reverse tr...
# 22  Human immunodeficiency virus type 1 reverse tr...
# 23  Human immunodeficiency virus type 1 reverse tr...
# 24  Human immunodeficiency virus type 1 reverse tr...
# 25  Human immunodeficiency virus type 1 reverse tr...
# 26  Human immunodeficiency virus type 1 reverse tr...
# 27                         Matrix metalloproteinase 9
# 28                         Matrix metalloproteinase 9
# 9                   triple bond  9.124939
# 10                  triple bond  9.124939
# 11                  triple bond  9.124939
# 12                  triple bond  9.124939
# 13                  triple bond  9.124939
# 14                  triple bond  9.124939
# 15                          NaN  4.638272
# 16                          NaN  4.638272
# 17                          NaN  4.638272
# 18                          NaN  4.638272
# 19                          NaN  4.638272
# 20                          NaN  4.638272
# 21                          NaN  6.638272
# 22                          NaN  6.638272
# 23                          NaN  6.638272
# 24                          NaN  6.638272
# 25                          NaN  6.638272
# 26                          NaN  6.638272
# 27              hydroxamic acid  8.522879
# 28  Oxygen-nitrogen single bond  8.522879
# 29          hydroxamate_warhead  8.522879

# %%
# Number of unique drugs
num_unique_drugs = df['drug_id'].nunique()
print(f"🔢 Unique drugs: {num_unique_drugs}")
# Out:
# 🔢 Unique drugs: 850

# %%
df['target'].unique()
# Out:
# array(['Human immunodeficiency virus type 1 reverse transcriptase',
#        'Matrix metalloproteinase 9', 'Matrix metalloproteinase 13',
#        'Steroid 5-alpha-reductase 2', 'Androgen Receptor',
#        'Xanthine dehydrogenase', 'FK506-binding protein 1A',
#        'Human immunodeficiency virus type 1 protease', 'Cyclophilin A',
#        'Ileal bile acid transporter', 'Nitric oxide synthase, inducible',
#        'Matrix metalloproteinase-1', 'Matrix metalloproteinase-2',
#        'Matrix metalloproteinase 3', 'Tyrosine-protein kinase SRC',
#        'Serotonin 1d (5-HT1d) receptor', 'Carbonic anhydrase II',
#        'Dihydrofolate reductase', 'Cyclooxygenase-2', 'Aldose reductase',
#        'Thymidylate synthase', 'Cytochrome P450 17A1',
#        'Muscarinic acetylcholine receptor M3',
#        'Farnesyl diphosphate synthase', 'HMG-CoA reductase',
#        'Epidermal growth factor receptor erbB1',
#        'Receptor protein-tyrosine kinase erbB-2',
#        'Angiotensin-converting enzyme', 'Neuraminidase',
#        'Mu opioid receptor', 'Plasminogen activator inhibitor-1',
#        'Kappa opioid receptor', 'LDL-associated phospholipase A2',
#        'Histone deacetylase 1', 'DNA topoisomerase I',
#        'Acetylcholinesterase', 'Neurokinin 1 receptor',
#        'Type-1 angiotensin II receptor', 'Dihydroorotate dehydrogenase',
#        'Endothelin receptor ET-A', 'Estrogen receptor alpha',
#        'Progesterone receptor', 'Cytochrome P450 19A1',
#        'Thromboxane-A synthase', 'Serotonin 1b (5-HT1b) receptor',
#        'Mitogen-activated protein kinase kinase kinase 9',
#        'Mitogen-activated protein kinase kinase kinase 10',
#        'Mitogen-activated protein kinase kinase kinase 11',
#        'Isoleucyl-tRNA synthetase', 'Vasopressin V2 receptor',
#        'Melanocortin receptor 1', 'Arachidonate 5-lipoxygenase',
#        'Protein kinase C beta', 'Pancreatic lipase',
#        'Matrix metalloproteinase 7', 'Dopamine D2 receptor',
#        'Steryl-sulfatase', 'Glucocorticoid receptor',
#        'Estrogen receptor beta', 'Cyclin-dependent kinase 1', 'HERG',
#        'Dipeptidyl peptidase IV', 'Phosphodiesterase 5A', 'Thrombin',
#        'Bacterial dihydrofolate reductase', 'Histamine H1 receptor',
#        'Neurokinin 2 receptor', 'Muscarinic acetylcholine receptor M4',
#        'Angiotensin II type 2 (AT-2) receptor',
#        'Retinoic acid receptor alpha',
#        'Muscarinic acetylcholine receptor M1',
#        'Dual specificity mitogen-activated protein kinase kinase 1',
#        'Vascular endothelial growth factor receptor 2',
#        'MAP kinase p38 alpha', 'Cyclin-dependent kinase 2',
#        'Serotonin 1a (5-HT1a) receptor', 'Ghrelin receptor',
#        'Carbonic anhydrase I', 'Dihydropyrimidine dehydrogenase',
#        'Phospholipase A2 group IIA',
#        'Platelet-derived growth factor receptor beta',
#        'Prostanoid IP receptor', 'Endothelin receptor ET-B',
#        'Stem cell growth factor receptor',
#        'Tyrosine-protein kinase receptor FLT3',
#        'Cholesteryl ester transfer protein',
#        'Peroxisome proliferator-activated receptor alpha', 'Tyrosinase',
#        'Thymidine phosphorylase',
#        'Peroxisome proliferator-activated receptor gamma',
#        'Cytochrome P450 11A1', 'Squalene synthetase',
#        'Human herpesvirus 1 DNA polymerase', 'Dopamine transporter',
#        'Tyrosine-protein kinase TIE-2', 'Serotonin 2a (5-HT2a) receptor',
#        'Thromboxane A2 receptor',
#        'Peroxisome proliferator-activated receptor delta',
#        'Serotonin 4 (5-HT4) receptor',
#        'Gonadotropin-releasing hormone receptor', 'Histone deacetylase 2',
#        'Histone deacetylase 6', 'Alpha-galactosidase A',
#        'Cyclin-dependent kinase 6', 'Cannabinoid CB1 receptor',
#        'Glycogen synthase kinase-3 beta', 'Adenosine A3 receptor',
#        'Voltage-gated N-type calcium channel alpha-1B subunit',
#        'Norepinephrine transporter', 'G protein-coupled receptor 44',
#        'Coagulation factor X', 'Tyrosine-protein kinase ABL',
#        'Beta-1 adrenergic receptor',
#        'Platelet activating factor receptor', 'Cathepsin K',
#        'Oxytocin receptor', 'Receptor protein-tyrosine kinase erbB-4',
#        'Human immunodeficiency virus type 1 integrase', 'ADAM17',
#        'Vanilloid receptor', 'Vitamin D receptor',
#        'Interleukin-8 receptor B', 'Interleukin-8 receptor A',
#        'Bradykinin B1 receptor', 'Neurokinin 3 receptor',
#        'Prostanoid DP receptor',
#        'Macrophage colony stimulating factor receptor',
#        'Equilibrative nucleoside transporter 1',
#        'PI3-kinase p110-delta subunit', 'PI3-kinase p110-gamma subunit',
#        'Tyrosine-protein kinase Lyn',
#        'Calcitonin gene-related peptide type 1 receptor',
#        'Adenosine A1 receptor', 'Histone deacetylase 3',
#        'Monoamine oxidase B',
#        'Intermediate conductance calcium-activated potassium channel protein 4',
#        'Histone deacetylase 8', 'Purinergic receptor P2Y12',
#        'P-glycoprotein 1', 'Solute carrier family 22 member 12',
#        'C-X-C chemokine receptor type 4',
#        'Hepatocyte growth factor receptor',
#        'ALK tyrosine kinase receptor', 'GAR transformylase',
#        'Monoamine oxidase A', 'Fibroblast growth factor receptor 3',
#        'Tyrosine-protein kinase JAK2', 'Tyrosine-protein kinase JAK3',
#        'Neurotensin receptor 1', 'Glucagon-like peptide 1 receptor',
#        'Corticotropin releasing factor receptor 1',
#        'Histamine H2 receptor', 'Histone deacetylase 11',
#        'Histamine H3 receptor', 'Serine/threonine-protein kinase PLK1',
#        'Serine/threonine-protein kinase Aurora-A',
#        'Serine/threonine-protein kinase Aurora-B',
#        'Lysosomal alpha-glucosidase',
#        'Acyl coenzyme A:cholesterol acyltransferase 1',
#        'Beta-2 adrenergic receptor', 'Matrix metalloproteinase 14',
#        'Smoothened homolog', 'Nerve growth factor receptor Trk-A',
#        'Sodium/glucose cotransporter 2',
#        'Insulin-like growth factor I receptor',
#        'DNA-(apurinic or apyrimidinic site) lyase',
#        'Neuropeptide Y receptor type 5',
#        'Tyrosine-protein kinase receptor RET',
#        'Serine/threonine-protein kinase mTOR',
#        'Apoptosis regulator Bcl-X', 'Ceramide glucosyltransferase',
#        'Maltase-glucoamylase', 'Mineralocorticoid receptor',
#        'Tyrosine-protein kinase JAK1', 'Adenosine A2a receptor',
#        'Poly [ADP-ribose] polymerase 2', 'Poly [ADP-ribose] polymerase-1',
#        'Phosphodiesterase 10A',
#        'Vascular endothelial growth factor receptor 3',
#        'Cysteinyl leukotriene receptor 1', 'Cyclin-dependent kinase 7',
#        'Cyclin-dependent kinase 9',
#        'Serine/threonine-protein kinase Chk1',
#        'Transient receptor potential cation channel subfamily M member 8',
#        'Tyrosine-protein kinase HCK', 'Cyclin-dependent kinase 5',
#        'Cyclin-dependent kinase 4', 'Cholecystokinin A receptor',
#        'Anandamide amidohydrolase', 'C-C chemokine receptor type 5',
#        'Casein kinase II alpha', 'Nicotinamide phosphoribosyltransferase',
#        '11-beta-hydroxysteroid dehydrogenase 1', 'P2X purinoceptor 7',
#        'Phosphodiesterase 3A', 'Muscarinic acetylcholine receptor M2',
#        'Calcium sensing receptor', 'Kinesin-like protein 1',
#        'Serotonin transporter', 'Serotonin 2c (5-HT2c) receptor',
#        'Dopamine D3 receptor', 'Histamine H4 receptor',
#        'Tyrosine-protein kinase BTK', '5-lipoxygenase activating protein',
#        'Serine/threonine-protein kinase B-raf', 'Delta opioid receptor',
#        'c-Jun N-terminal kinase 1', 'c-Jun N-terminal kinase 2',
#        'c-Jun N-terminal kinase 3', 'Cannabinoid CB2 receptor',
#        'Solute carrier family 22 member 6',
#        'Solute carrier family 22 member 11',
#        'Solute carrier family 22 member 8',
#        'Vascular endothelial growth factor receptor 1', 'Renin',
#        'Glucagon receptor', 'Beta-glucocerebrosidase',
#        'Tyrosine-protein kinase SYK', 'C-C chemokine receptor type 9',
#        'C-C chemokine receptor type 2', 'Phosphodiesterase 9A',
#        'Serotonin 3a (5-HT3a) receptor', 'Thioredoxin',
#        'Sodium channel protein type IX alpha subunit', 'Plasminogen',
#        'Metabotropic glutamate receptor 5', 'Amyloid-beta A4 protein',
#        'PI3-kinase p110-alpha subunit',
#        'Acyl coenzyme A:cholesterol acyltransferase 2',
#        'Receptor tyrosine-protein kinase erbB-3', 'GABA transporter 1',
#        'Glutathione reductase', 'Cytidine deaminase',
#        'Carbonic anhydrase XII', 'Insulin receptor',
#        'TGF-beta receptor type I', 'Tyrosine-protein kinase TYK2',
#        'Sphingosine 1-phosphate receptor Edg-1',
#        'Metabotropic glutamate receptor 2', 'Apoptosis regulator Bcl-2',
#        'C-C chemokine receptor type 1', 'Matrix metalloproteinase 8',
#        'Free fatty acid receptor 2', 'PI3-kinase p110-beta subunit',
#        'Serine/threonine-protein kinase PLK4',
#        'Sodium channel protein type V alpha subunit',
#        'Glycogen synthase kinase-3 alpha', 'DNA-dependent protein kinase',
#        'MAP kinase ERK2', 'Sodium channel protein type X alpha subunit',
#        'Prostanoid EP4 receptor', 'MAP kinase ERK1',
#        'Indoleamine 2,3-dioxygenase', 'Thyroid peroxidase',
#        'Probable protein-cysteine N-palmitoyltransferase porcupine',
#        'Egl nine homolog 1', 'Egl nine homolog 3',
#        'G-protein coupled receptor 84', 'Proteinase activated receptor 4',
#        'Alpha-1d adrenergic receptor', 'Matrix metalloproteinase 12',
#        'Glutaminase kidney isoform, mitochondrial',
#        'Cytochrome P450 26A1',
#        'Proto-oncogene tyrosine-protein kinase ROS',
#        'Tyrosine-protein kinase receptor UFO',
#        'Alpha-1a adrenergic receptor', 'Catechol O-methyltransferase',
#        'Epoxide hydratase', 'Autotaxin', 'Dipeptidyl peptidase I',
#        'Fibroblast growth factor receptor 2',
#        'Fibroblast growth factor receptor 1', 'Transthyretin',
#        'Mitogen-activated protein kinase kinase kinase 5',
#        'Voltage-gated potassium channel subunit Kv1.5',
#        'Receptor-type tyrosine-protein phosphatase beta',
#        'Sodium/hydrogen exchanger 3',
#        'Platelet-derived growth factor receptor alpha',
#        'Ephrin type-B receptor 4', 'Beta-secretase 1',
#        'Hypoxia-inducible factor prolyl hydroxylase 1',
#        'Focal adhesion kinase 1', 'Fibroblast growth factor receptor 4',
#        'Receptor-interacting serine/threonine-protein kinase 1',
#        'Sodium/glucose cotransporter 1',
#        'Interleukin-1 receptor-associated kinase 4',
#        'Sphingosine kinase 2',
#        'Isocitrate dehydrogenase [NADP] cytoplasmic',
#        'DNA (cytosine-5)-methyltransferase 1',
#        'Serotonin 6 (5-HT6) receptor', 'Serine-protein kinase ATR',
#        'Parathyroid hormone receptor',
#        'Macrophage migration inhibitory factor',
#        'Synaptic vesicular amine transporter', 'Glycine transporter 1',
#        'Toll-like receptor 4', 'Proteinase-activated receptor 1',
#        'Complement factor D', 'Serine/threonine-protein kinase WEE1',
#        'Alcohol dehydrogenase class III', 'Leukocyte elastase',
#        'Rho-associated protein kinase 2',
#        'Diacylglycerol O-acyltransferase 1', 'Monoglyceride lipase',
#        'Myeloperoxidase', 'Endothelial PAS domain-containing protein 1',
#        'Nonstructural protein 5A',
#        'Dual specificity mitogen-activated protein kinase kinase 2',
#        'Cell division cycle 7-related protein kinase',
#        'Prostanoid EP2 receptor',
#        'Protein arginine N-methyltransferase 5',
#        'Dual specificity protein kinase TTK', 'GTPase KRas', 'Nischarin',
#        'Serine/threonine-protein kinase Chk2', 'Phosphodiesterase 4D',
#        'Serine/threonine-protein kinase RAF', 'Apoptosis regulator Bcl-W',
#        'P2X purinoceptor 3', 'Enoyl-[acyl-carrier-protein] reductase',
#        'Complement factor B', 'DNA topoisomerase II alpha',
#        'Vasopressin V1a receptor', 'Protein-tyrosine phosphatase 2C',
#        'Isocitrate dehydrogenase [NADP], mitochondrial',
#        'FAD-dependent decaprenylphosphoryl-beta-D-ribofuranose 2-oxidase',
#        'Cytochrome P450 51', 'Aldehyde dehydrogenase',
#        'Protein tyrosine kinase 2 beta', 'Serotonin 1f (5-HT1f) receptor',
#        'Replicase polyprotein 1ab', 'Leukotriene A4 hydrolase', 'ADAMTS5',
#        'NT-3 growth factor receptor',
#        'Neurotrophic tyrosine kinase receptor type 2', 'Galectin-3',
#        'Cholesterol 24-hydroxylase',
#        '1-phosphatidylinositol 3-phosphate 5-kinase',
#        'Niemann-Pick C1-like protein 1',
#        'Advanced glycosylation end product-specific receptor',
#        'Polymerase acidic protein',
#        'Lysine-specific histone demethylase 1', 'Exportin-1',
#        'Hepatitis C virus NS5B RNA-dependent RNA polymerase',
#        'Polymerase basic protein 2'], dtype=object)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load BioGPT model from Microsoft
model_name = "microsoft/BioGPT-Large"
biogpt_tokenizer = AutoTokenizer.from_pretrained(model_name)
biogpt_model = AutoModelForCausalLM.from_pretrained(model_name)

print("✅ BioGPT-Large loaded and ready.")
# Out:
# ✅ BioGPT-Large loaded and ready.

# %%
save_directory = "./saved_models/biogpt-large"

# Save model
biogpt_model.save_pretrained(save_directory)

# Save tokenizer
biogpt_tokenizer.save_pretrained(save_directory)

print("📦 BioGPT-Large saved to:", save_directory)
# Out:
# 📦 BioGPT-Large saved to: ./saved_models/biogpt-large

# %%
pip install peft bitsandbytes accelerate transformers datasets
# Out:
# Requirement already satisfied: peft in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (0.15.2)Note: you may need to restart the kernel to use updated packages.
#
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.1-py3-none-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: accelerate in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (1.8.1)
# Requirement already satisfied: transformers in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (4.41.0)
# Requirement already satisfied: datasets in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (24.2)
# Requirement already satisfied: psutil in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (6.0.0)
# Requirement already satisfied: pyyaml in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (2.5.1)
# Requirement already satisfied: tqdm in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (4.67.1)
# Requirement already satisfied: safetensors in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (0.5.2)
# Requirement already satisfied: huggingface_hub>=0.25.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from peft) (0.27.1)
# Requirement already satisfied: filelock in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.13.0->peft) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.13.0->peft) (4.12.2)
# Requirement already satisfied: networkx in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.13.0->peft) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.13.0->peft) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.13.0->peft) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from datasets) (15.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.1.1)
# Requirement already satisfied: xxhash in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.9.8)
# Requirement already satisfied: idna>=2.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from tqdm->peft) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\konde\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading bitsandbytes-0.46.1-py3-none-win_amd64.whl (72.2 MB)
#    ---------------------------------------- 0.0/72.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/72.2 MB 837.5 kB/s eta 0:01:26
#    ---------------------------------------- 0.8/72.2 MB 1.0 MB/s eta 0:01:11
#     --------------------------------------- 1.3/72.2 MB 1.2 MB/s eta 0:00:58
#     --------------------------------------- 1.6/72.2 MB 1.3 MB/s eta 0:00:54
#    - -------------------------------------- 1.8/72.2 MB 1.4 MB/s eta 0:00:50
#    - -------------------------------------- 2.1/72.2 MB 1.4 MB/s eta 0:00:51
#    - -------------------------------------- 2.4/72.2 MB 1.4 MB/s eta 0:00:52
#    - -------------------------------------- 2.6/72.2 MB 1.3 MB/s eta 0:00:53
#    - -------------------------------------- 2.9/72.2 MB 1.3 MB/s eta 0:00:53
#    - -------------------------------------- 3.1/72.2 MB 1.3 MB/s eta 0:00:53
#    - -------------------------------------- 3.4/72.2 MB 1.3 MB/s eta 0:00:53
#    -- ------------------------------------- 3.7/72.2 MB 1.3 MB/s eta 0:00:54
#    -- ------------------------------------- 3.9/72.2 MB 1.3 MB/s eta 0:00:53
#    -- ------------------------------------- 4.2/72.2 MB 1.3 MB/s eta 0:00:53
#    -- ------------------------------------- 4.5/72.2 MB 1.3 MB/s eta 0:00:54
#    --------------------------------- ------ 60.6/72.2 MB 1.2 MB/s eta 0:00:10
#    --------------------------------- ------ 61.3/72.2 MB 1.2 MB/s eta 0:00:09
#    ---------------------------------- ----- 62.4/72.2 MB 1.3 MB/s eta 0:00:08
#    ----------------------------------- ---- 63.7/72.2 MB 1.3 MB/s eta 0:00:07
#    ------------------------------------ --- 66.1/72.2 MB 1.3 MB/s eta 0:00:05
#    -------------------------------------- - 68.9/72.2 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------------  72.1/72.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 72.2/72.2 MB 1.5 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.46.1

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("data/cleaned_clinical_drugs_dataset.csv")
print("✅ Loaded:", df.shape)
df.head(30)
# Out:
# ✅ Loaded: (553992, 19)
#          drug_id   drug_name  \
# 0   CHEMBL223228   EFAVIRENZ
# 1   CHEMBL223228   EFAVIRENZ
# 2   CHEMBL223228   EFAVIRENZ
# 3   CHEMBL223228   EFAVIRENZ
# 4   CHEMBL223228   EFAVIRENZ
# 5   CHEMBL223228   EFAVIRENZ
# 6   CHEMBL223228   EFAVIRENZ
# 7   CHEMBL223228   EFAVIRENZ
# 8   CHEMBL223228   EFAVIRENZ
# 9   CHEMBL223228   EFAVIRENZ
# 10  CHEMBL223228   EFAVIRENZ
# 11  CHEMBL223228   EFAVIRENZ
# 12  CHEMBL223228   EFAVIRENZ
# 13  CHEMBL223228   EFAVIRENZ
# 14  CHEMBL223228   EFAVIRENZ
# 15      CHEMBL57  NEVIRAPINE
# 16      CHEMBL57  NEVIRAPINE
# 17      CHEMBL57  NEVIRAPINE
# 18      CHEMBL57  NEVIRAPINE
# 19      CHEMBL57  NEVIRAPINE
# 20      CHEMBL57  NEVIRAPINE
# 21      CHEMBL57  NEVIRAPINE
# 22      CHEMBL57  NEVIRAPINE
# 23      CHEMBL57  NEVIRAPINE
# 24      CHEMBL57  NEVIRAPINE
# 25      CHEMBL57  NEVIRAPINE
# 26      CHEMBL57  NEVIRAPINE
# 27  CHEMBL440498    CTS-1027
# 28  CHEMBL440498    CTS-1027
# 29  CHEMBL440498    CTS-1027
#
#                                                SMILES  logD  logP     psa  \
# 0        O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1  4.46  4.46   38.33
# 1        O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1  4.46  4.46   38.33
# 2        O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1  4.46  4.46   38.33
# 3        O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1  4.46  4.46   38.33
# 4        O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1  4.46  4.46   38.33
# 5        O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1  4.46  4.46   38.33
# 6        O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1  4.46  4.46   38.33
# 17  Human immunodeficiency virus 1  SINGLE PROTEIN
# 18  Human immunodeficiency virus 1  SINGLE PROTEIN
# 19  Human immunodeficiency virus 1  SINGLE PROTEIN
# 20  Human immunodeficiency virus 1  SINGLE PROTEIN
# 21  Human immunodeficiency virus 1  SINGLE PROTEIN
# 22  Human immunodeficiency virus 1  SINGLE PROTEIN
# 23  Human immunodeficiency virus 1  SINGLE PROTEIN
# 24  Human immunodeficiency virus 1  SINGLE PROTEIN
# 25  Human immunodeficiency virus 1  SINGLE PROTEIN
# 26  Human immunodeficiency virus 1  SINGLE PROTEIN
# 27                    Homo sapiens  SINGLE PROTEIN
# 28                    Homo sapiens  SINGLE PROTEIN
# 29                    Homo sapiens  SINGLE PROTEIN
#
#                                   mechanism_of_action  \
# 0   Human immunodeficiency virus type 1 reverse tr...
# 1   Human immunodeficiency virus type 1 reverse tr...
# 2   Human immunodeficiency virus type 1 reverse tr...
# 3   Human immunodeficiency virus type 1 reverse tr...
# 4   Human immunodeficiency virus type 1 reverse tr...
# 5   Human immunodeficiency virus type 1 reverse tr...
# 6   Human immunodeficiency virus type 1 reverse tr...
# 7   Human immunodeficiency virus type 1 reverse tr...
# 8   Human immunodeficiency virus type 1 reverse tr...
# 9   Human immunodeficiency virus type 1 reverse tr...
# 10  Human immunodeficiency virus type 1 reverse tr...
# 11  Human immunodeficiency virus type 1 reverse tr...
# 12  Human immunodeficiency virus type 1 reverse tr...
# 13  Human immunodeficiency virus type 1 reverse tr...
# 14  Human immunodeficiency virus type 1 reverse tr...
# 15  Human immunodeficiency virus type 1 reverse tr...
# 16  Human immunodeficiency virus type 1 reverse tr...
# 17  Human immunodeficiency virus type 1 reverse tr...
# 18  Human immunodeficiency virus type 1 reverse tr...
# 19  Human immunodeficiency virus type 1 reverse tr...
# 20  Human immunodeficiency virus type 1 reverse tr...
# 21  Human immunodeficiency virus type 1 reverse tr...
# 22  Human immunodeficiency virus type 1 reverse tr...
# 23  Human immunodeficiency virus type 1 reverse tr...
# 24  Human immunodeficiency virus type 1 reverse tr...
# 25  Human immunodeficiency virus type 1 reverse tr...
# 26  Human immunodeficiency virus type 1 reverse tr...
# 27               Matrix metalloproteinase 9 inhibitor
# 28               Matrix metalloproteinase 9 inhibitor
# 29               Matrix metalloproteinase 9 inhibitor
#
#                          efo_term         efo_id  \
# 0                            AIDS    EFO:0000765
# 1        immunodeficiency disease  MONDO:0021094
# 2        type 2 diabetes mellitus  MONDO:0005148
# 3     hepatitis C virus infection    EFO:0003047
# 4                       infection    EFO:0000544
# 5           non-Hodgkins lymphoma    EFO:0005952
# 6                         malaria    EFO:0001068
# 7                        neoplasm    EFO:0000616
# 8            pancreatic carcinoma    EFO:0002618
# 9                    tuberculosis  MONDO:0018076
# 10                  viral disease    EFO:0000763
# 11                HIV-1 infection    EFO:0000180
# 12                  HIV infection    EFO:0000764
# 13                prostate cancer  MONDO:0008315
# 14  triple-negative breast cancer    EFO:0005537
# 15                           AIDS    EFO:0000765
# 16                      infection    EFO:0000544
# 17                   tuberculosis  MONDO:0018076
# 18                  viral disease    EFO:0000763
# 19                HIV-1 infection    EFO:0000180
# 20                  HIV infection    EFO:0000764
# 21                           AIDS    EFO:0000765
# 22                      infection    EFO:0000544
# 23                   tuberculosis  MONDO:0018076
# 24                  viral disease    EFO:0000763
# 25                HIV-1 infection    EFO:0000180
# 26                  HIV infection    EFO:0000764
# 27    hepatitis C virus infection    EFO:0003047
# 28    hepatitis C virus infection    EFO:0003047
# 29    hepatitis C virus infection    EFO:0003047
#
#                                  mesh_heading  mesh_id  \
# 0          Acquired Immunodeficiency Syndrome  D000163
# 1                         Autoimmune Diseases  D001327
# 2                   Diabetes Mellitus, Type 2  D003924
# 3                                 Hepatitis C  D006526
# 4                                  Infections  D007239
# 5                       Lymphoma, Non-Hodgkin  D008228
# 6                                     Malaria  D008288
# 7                                   Neoplasms  D009369
# 8                        Pancreatic Neoplasms  D010190
# 9                                Tuberculosis  D014376
# 10                             Virus Diseases  D014777
# 11                             HIV Infections  D015658
# 12                             HIV Infections  D015658
# 13  Prostatic Neoplasms, Castration-Resistant  D064129
# 14           Triple Negative Breast Neoplasms  D064726
# 15         Acquired Immunodeficiency Syndrome  D000163
# 16                                 Infections  D007239
# 17                               Tuberculosis  D014376
# 18                             Virus Diseases  D014777
# 19                             HIV Infections  D015658
# 20                             HIV Infections  D015658
# 21         Acquired Immunodeficiency Syndrome  D000163
# 22                                 Infections  D007239
# 23                               Tuberculosis  D014376
# 24                             Virus Diseases  D014777
# 25                             HIV Infections  D015658
# 26                             HIV Infections  D015658
# 27                                Hepatitis C  D006526
# 28                                Hepatitis C  D006526
# 29                                Hepatitis C  D006526
#
#                  toxicity_alert     pIC50
# 0                   triple bond  9.124939
# 1                   triple bond  9.124939
# 2                   triple bond  9.124939
# 3                   triple bond  9.124939
# 4                   triple bond  9.124939
# 5                   triple bond  9.124939
# 6                   triple bond  9.124939
# 7                   triple bond  9.124939
# 8                   triple bond  9.124939
# 9                   triple bond  9.124939
# 10                  triple bond  9.124939
# 11                  triple bond  9.124939
# 12                  triple bond  9.124939
# 13                  triple bond  9.124939
# 14                  triple bond  9.124939
# 15                          NaN  4.638272
# 16                          NaN  4.638272
# 17                          NaN  4.638272
# 18                          NaN  4.638272
# 19                          NaN  4.638272
# 20                          NaN  4.638272
# 21                          NaN  6.638272
# 22                          NaN  6.638272
# 23                          NaN  6.638272
# 24                          NaN  6.638272
# 25                          NaN  6.638272
# 26                          NaN  6.638272
# 27              hydroxamic acid  8.522879
# 28  Oxygen-nitrogen single bond  8.522879
# 29          hydroxamate_warhead  8.522879

# %%
columns_to_keep = [
    "drug_name", "SMILES", "target", "mechanism_of_action",
    "pIC50", "efo_term", "mesh_heading"
]

df = df[columns_to_keep].dropna()
print("🧼 After cleaning:", df.shape)
# Out:
# 🧼 After cleaning: (553987, 7)

# %%
def create_prompt(row):
    prompt = f"""### Instruction:
Given the following drug information, predict the target and mechanism.

Drug Name: {row['drug_name']}
SMILES: {row['SMILES']}

### Response:
Target: {row['target']}
Mechanism: {row['mechanism_of_action']}"""
    return prompt

df['text'] = df.apply(create_prompt, axis=1)
formatted_df = df[['text']].rename(columns={'text': 'text'})

print("📄 Sample Prompt:\n", formatted_df.iloc[0]['text'])
# Out:
# 📄 Sample Prompt:
#  ### Instruction:
# Given the following drug information, predict the target and mechanism.
#
# Drug Name: EFAVIRENZ
# SMILES: O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1
#
# ### Response:
# Target: Human immunodeficiency virus type 1 reverse transcriptase
# Mechanism: Human immunodeficiency virus type 1 reverse transcriptase inhibitor

# %%
import json

output_path = "formatted_data.jsonl"

with open(output_path, "w", encoding="utf-8") as f:
    for record in formatted_df['text']:
        json.dump({"text": record}, f)
        f.write("\n")

print(f"💾 Saved formatted dataset to {output_path}")
# Out:
# 💾 Saved formatted dataset to formatted_data.jsonl

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model
import torch

# Load tokenizer and model
model_name = "microsoft/BioGPT-Large"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load the model in FP16 and manually push to GPU
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16
).to("cuda")

# Prepare for LoRA training (no quantization)
model = prepare_model_for_kbit_training(model)

# LoRA config
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],  # fallback: try ["c_attn"] or inspect if error
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, lora_config)

# ✅ Show trainable parameters
def print_trainable_parameters(model):
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    total = sum(p.numel() for p in model.parameters())
    print(f"✅ Trainable params: {trainable:,} / {total:,} ({100 * trainable / total:.2f}%)")

print_trainable_parameters(model)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 13
#       7 tokenizer = AutoTokenizer.from_pretrained(model_name)
#       9 # Load the model in FP16 and manually push to GPU
#      10 model = AutoModelForCausalLM.from_pretrained(
#      11     model_name,
#      12     torch_dtype=torch.float16
# ---> 13 ).to("cuda")
#      15 # Prepare for LoRA training (no quantization)
#      16 model = prepare_model_for_kbit_training(model)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\modeling_utils.py:2576, in PreTrainedModel.to(self, *args, **kwargs)
#    2571     if dtype_present_in_args:
#    2572         raise ValueError(
#    2573             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2574             " `dtype` by passing the correct `torch_dtype` argument."
#    2575         )
# -> 2576 return super().to(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1355, in Module.to(self, *args, **kwargs)
#    1352         else:
#    1353             raise
# -> 1355 return self._apply(convert)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:942, in Module._apply(self, fn, recurse)
#     938 # Tensors stored in modules are graph leaves, and we don't want to
#     939 # track autograd history of `param_applied`, so we have to use
#     940 # `with torch.no_grad():`
#     941 with torch.no_grad():
# --> 942     param_applied = fn(param)
#     943 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     945 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1341, in Module.to.<locals>.convert(t)
#    1334     if convert_to_format is not None and t.dim() in (4, 5):
#    1335         return t.to(
#    1336             device,
#    1337             dtype if t.is_floating_point() or t.is_complex() else None,
#    1338             non_blocking,
#    1339             memory_format=convert_to_format,
#    1340         )
# -> 1341     return t.to(
#    1342         device,
#    1343         dtype if t.is_floating_point() or t.is_complex() else None,
#    1344         non_blocking,
#    1345     )
#    1346 except NotImplementedError as e:
#    1347     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\cuda\__init__.py:363, in _lazy_init()
#     358     raise RuntimeError(
#     359         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     360         "multiprocessing, you must use the 'spawn' start method"
#     361     )
#     362 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 363     raise AssertionError("Torch not compiled with CUDA enabled")
#     364 if _cudart is None:
#     365     raise AssertionError(
#     366         "libcudart functions unavailable. It looks like you have a broken build?"
#     367     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
# Count number of lines in the saved JSONL file
with open("formatted_data.jsonl", "r", encoding="utf-8") as f:
    num_lines = sum(1 for _ in f)

print(f"📊 Lines saved in formatted_data.jsonl: {num_lines}")
print(f"📁 Expected rows: {len(formatted_df)}")
# Out:
# 📊 Lines saved in formatted_data.jsonl: 553987
# 📁 Expected rows: 553987

# %%
from transformers import AutoModelForCausalLM
from peft import LoraConfig, get_peft_model, TaskType

# Define LoRA configuration
peft_config = LoraConfig(
    r=4,  # Lower rank to reduce trainable parameters
    lora_alpha=16,
    target_modules=["q_proj"],  # Only adapting query projection layer
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM
)

# Load base BioGPT model
base_model = AutoModelForCausalLM.from_pretrained("microsoft/BioGPT-Large")

# Apply LoRA configuration
model = get_peft_model(base_model, peft_config)

# Print trainable parameters
model.print_trainable_parameters()
# Out:
# trainable params: 614,400 || all params: 1,571,803,200 || trainable%: 0.039088863033234694

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import LoraConfig, get_peft_model, TaskType
from transformers import TrainingArguments, Trainer, DataCollatorForLanguageModeling
import torch

# Step 1: Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/BioGPT-Large")

# Step 2: Load formatted dataset
dataset = load_dataset("json", data_files="formatted_data.jsonl", split="train")

# Step 3: Tokenization
def tokenize_function(example):
    texts = [p + " " + c for p, c in zip(example["prompt"], example["completion"])]
    return tokenizer(texts, padding="max_length", truncation=True, max_length=512)

tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Step 4: LoRA configuration (already optimized)
peft_config = LoraConfig(
    r=4,
    lora_alpha=16,
    target_modules=["q_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM
)

# Step 5: Load base model and apply LoRA
base_model = AutoModelForCausalLM.from_pretrained("microsoft/BioGPT-Large")
model = get_peft_model(base_model, peft_config)
model.print_trainable_parameters()

# Step 6: Training arguments
training_args = TrainingArguments(
    output_dir="./biogpt-lora-llm4mol",
    per_device_train_batch_size=4,       # Tune if GPU OOM
    gradient_accumulation_steps=4,       # Effective batch size = 16
    num_train_epochs=1,
    learning_rate=2e-4,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=50,
    save_strategy="epoch",
    fp16=torch.cuda.is_available(),      # Use FP16 if CUDA available
    report_to="none"
)

# Step 7: Data collator (for causal LM)
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# Step 8: Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    data_collator=data_collator
)

# Step 9: Train the model
trainer.train()
# Out:
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers and GPU quantization are unavailable.
# C:\Users\konde\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\data\metrics\__init__.py:19: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.1)
#   from scipy.stats import pearsonr, spearmanr
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1472, in _LazyModule._get_module(self, module_name)
#    1471 try:
# -> 1472     return importlib.import_module("." + module_name, self.__name__)
#    1473 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\trainer.py:59
#      58 from .configuration_utils import PretrainedConfig
# ---> 59 from .data.data_collator import DataCollator, DataCollatorWithPadding, default_data_collator
#      60 from .debug_utils import DebugOption, DebugUnderflowOverflow
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\data\__init__.py:26
#      15 from .data_collator import (
#      16     DataCollatorForLanguageModeling,
#      17     DataCollatorForPermutationLanguageModeling,
#    (...)
#      24     default_data_collator,
#      25 )
# ---> 26 from .metrics import glue_compute_metrics, xnli_compute_metrics
#      27 from .processors import (
#      28     DataProcessor,
#      29     InputExample,
#    (...)
#      43     xnli_tasks_num_labels,
#      44 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\data\metrics\__init__.py:20
#      19     from scipy.stats import pearsonr, spearmanr
# ---> 20     from sklearn.metrics import f1_score, matthews_corrcoef
#      23 DEPRECATION_WARNING = (
#      24     "This metric will be removed from the library soon, metrics should be handled with the 🤗 Evaluate "
#      25     "library. You can have a look at this example script for pointers: "
#      26     "https://github.com/huggingface/transformers/blob/main/examples/pytorch/text-classification/run_glue.py"
#      27 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\__init__.py:83
#      79 from . import (
#      80     __check_build,  # noqa: F401
#      81     _distributor_init,  # noqa: F401
#      82 )
# ---> 83 from .base import clone
#      84 from .utils._show_versions import show_versions
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:19
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import estimator_html_repr
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\__init__.py:27
#      26 from .fixes import parse_version, threadpool_info
# ---> 27 from .murmurhash import murmurhash3_32
#      28 from .validation import (
#      29     _is_arraylike_not_scalar,
#      30     as_float_array,
#    (...)
#      39     indexable,
#      40 )
#
# File sklearn\utils\murmurhash.pyx:1, in init sklearn.utils.murmurhash()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 4
#       2 from transformers import AutoTokenizer, AutoModelForCausalLM
#       3 from peft import LoraConfig, get_peft_model, TaskType
# ----> 4 from transformers import TrainingArguments, Trainer, DataCollatorForLanguageModeling
#       5 import torch
#       7 # Step 1: Load tokenizer
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1462, in _LazyModule.__getattr__(self, name)
#    1460     value = self._get_module(name)
#    1461 elif name in self._class_to_module.keys():
# -> 1462     module = self._get_module(self._class_to_module[name])
#    1463     value = getattr(module, name)
#    1464 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1474, in _LazyModule._get_module(self, module_name)
#    1472     return importlib.import_module("." + module_name, self.__name__)
#    1473 except Exception as e:
# -> 1474     raise RuntimeError(
#    1475         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1476         f" traceback):\n{e}"
#    1477     ) from e
#
# RuntimeError: Failed to import transformers.trainer because of the following error (look up to see its traceback):
# numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
